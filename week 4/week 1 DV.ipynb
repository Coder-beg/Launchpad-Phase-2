# %% [markdown]
# # Install Libraries

# %%
# !pip install pandas numpy matplotlib seaborn

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read csv file

# %%
df = pd.read_csv("data.csv")

# %%
df.head(5)
# Out:
#   What is your age? When do you prefer to study?  \
# 0             20-22                      Morning
# 1             20-22                   Late Night
# 2             20-22                      Morning
# 3             20-22                   Late Night
# 4             20-22                      Evening
#
#   How many hours do you spend on screens daily? (including phone, laptop, tablets )  \
# 0                                  More than 7 hours
# 1                                        4 - 7 Hours
# 2                                  More than 7 hours
# 3                                        1 - 3 Hours
# 4                                  More than 7 hours
#
#   Do you prefer coffee or tea?  How many languages do you speak fluently?  \
# 0                       Coffee                                          3
# 1                          Tea                                          3
# 2                          Tea                                          3
# 3                          Tea                                          2
# 4                          Tea                                          3
#
#   What are your hobbies / interest?  How often do you exercise in a week?  \
# 0                          Traveling                            1-3 times
# 1                        Motorsports                    I do not exercise
# 2                          Traveling                    I do not exercise
# 3                          Traveling                            1-3 times
# 4                             Sports                            4-6 times
#
#   Which social media app do you prefer?  \
# 0                              Whatsapp
# 1                              Whatsapp
# 2                              Whatsapp
# 3                              Whatsapp
# 4                             Instagram
#
#   How do you primarily commute to work or school?  \
# 0                                         Walking
# 1                                             Car
# 2                                         Walking
# 3                                         Walking
# 4                                             Car
#
#   How many hours of sleep do you get on an average night?  \
# 0                                          7-9 hours
# 1                                          4-6 hours
# 2                                          4-6 hours
# 3                                          4-6 hours
# 4                                          7-9 hours
#
#   On average, how much water do you drink per day?  \
# 0                                       1-2 liters
# 1                                       1-2 liters
# 2                                       1-2 liters
# 3                                       1-2 liters
# 4                                       1-2 liters
#
#   What is your preferred method for staying informed about current events?
# 0                                       Social media
# 1                                       Social media
# 2                                       Social media
# 3                                       Social media
# 4                                       Social media

# %%
df.shape
# Out:
# (21, 12)

# %%
df.isnull().sum()
# Out:
# What is your age?                                                                    0
# When do you prefer to study?                                                         1
# How many hours do you spend on screens daily? (including phone, laptop, tablets )    0
# Do you prefer coffee or tea?                                                         0
# How many languages do you speak fluently?                                            0
# What are your hobbies / interest?                                                    0
# How often do you exercise in a week?                                                 0
# Which social media app do you prefer?                                                0
# How do you primarily commute to work or school?                                      0
# How many hours of sleep do you get on an average night?                              0
# On average, how much water do you drink per day?                                     0
# What is your preferred method for staying informed about current events?             0
# dtype: int64

# %%
a = df["When do you prefer to study?"].mode()
a[0]
# Out:
# 'Late Night'

# %%
df.fillna(a[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# What is your age?                                                                    0
# When do you prefer to study?                                                         0
# How many hours do you spend on screens daily? (including phone, laptop, tablets )    0
# Do you prefer coffee or tea?                                                         0
# How many languages do you speak fluently?                                            0
# What are your hobbies / interest?                                                    0
# How often do you exercise in a week?                                                 0
# Which social media app do you prefer?                                                0
# How do you primarily commute to work or school?                                      0
# How many hours of sleep do you get on an average night?                              0
# On average, how much water do you drink per day?                                     0
# What is your preferred method for staying informed about current events?             0
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Distribution of Age

# %%
plt.figure(figsize=(6, 4))

age_counts = df['What is your age?'].value_counts()
plt.bar(age_counts.index, age_counts.values, color='teal')
plt.title('Distribution of Age')
plt.xlabel('Age Groups')
plt.ylabel('Number of Students')
plt.show()

# %%
age_counts = df['What is your age?'].value_counts()
plt.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%')
plt.title("Distribution of Age")

plt.show()

# %% [markdown]
# ## Daily Screen Time (hours)

# %%
screen_time_counts = df["How many hours do you spend on screens daily? (including phone, laptop, tablets )"].value_counts()
plt.bar(screen_time_counts.index, screen_time_counts.values, color='khaki')
plt.title("Daily Screen Time")
plt.xlabel("Hours")
plt.xticks(rotation=45)
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.pie(screen_time_counts, labels=screen_time_counts.index, autopct='%1.1f%%')
plt.title("Daily Screen Time")

plt.show()

# %% [markdown]
# ## Coffee or Tea Preference

# %%
coffee_tea_counts = df["Do you prefer coffee or tea?"].value_counts()
plt.pie(coffee_tea_counts, labels=coffee_tea_counts.index, autopct='%1.1f%%', colors=['orange', 'skyblue', 'teal'])
plt.title("Coffee or Tea Preference")
plt.show()

# %%
# Preferred coffee or tea

plt.bar(coffee_tea_counts.index, coffee_tea_counts.values)
plt.title("Preferred Coffee or tea")
plt.xlabel("coffee/ Tea")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Preferred Study Time

# %%
# Preferred Study Time - Bar Chart

study_time_counts = df["When do you prefer to study?"].value_counts()
plt.bar(study_time_counts.index, study_time_counts.values)
plt.title("Preferred Study Time")
plt.xlabel("Time of Day")
plt.ylabel("Count")
plt.show()

# %%
plt.pie(study_time_counts, labels=study_time_counts.index, autopct='%1.1f%%')
plt.title("Study Time Preference")
plt.show()

# %% [markdown]
# ## Which social media app do you prefer?

# %%
# Social Media App Preference
social_media_counts = df['Which social media app do you prefer?'].value_counts()
plt.bar(social_media_counts.index, social_media_counts)
plt.title('Social Media App Preferences')
plt.xlabel('Social Media App Categories')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.show()

# %%
plt.pie(social_media_counts, labels=social_media_counts.index, autopct='%1.1f%%')
plt.title("Social Media App Preference")
plt.show()

# %% [markdown]
# ## What are your hobbies?

# %%
# What are your hobbies?
hobbies_media_counts = df['What are your hobbies / interest? '].value_counts()
plt.barh(hobbies_media_counts.index, hobbies_media_counts)
plt.title('Hobbies / interest')
plt.xlabel('Hobbies')
plt.ylabel('Number of Students')
plt.show()

# %%
plt.pie(hobbies_media_counts, labels=hobbies_media_counts.index, autopct='%1.1f%%')
plt.title("Hobbies / Interest")
plt.show()

# %% [markdown]
# The above pie chart is not preferred because of the number of slices.

# %% [markdown]
# ## Number of Languages Spoken

# %%
language_counts = df['How many languages do you speak fluently?'].value_counts()
plt.bar(language_counts.index, language_counts.values)
plt.title('Distribution of Number of Languages Spoken')
plt.xlabel('Number of Languages')
plt.ylabel('Number of Students')
plt.show()

# %%
plt.pie(language_counts, labels=language_counts.index, autopct='%1.1f%%')
plt.title("Distribution of Number of Languages Spoken")
plt.show()

# %% [markdown]
# ## Exercise Frequency per Week

# %%
exercise_counts = df["How often do you exercise in a week?"].value_counts()
plt.bar(exercise_counts.index, exercise_counts.values)
plt.title("Exercise Frequency per Week")
plt.xlabel("Frequency")
plt.xticks(rotation=45)
plt.ylabel("Count")
plt.show()

# %%
plt.pie(exercise_counts, labels=exercise_counts.index, autopct='%1.1f%%')
plt.title("Exercise Routine")
plt.show()

# %% [markdown]
# ## Primary Commute Method Distribution

# %%
Commute_counts = df["How do you primarily commute to work or school?"].value_counts()
plt.bar(Commute_counts.index, Commute_counts.values)
plt.title("Primary Commute Method Distribution")
plt.xlabel("Frequency")
plt.xticks(rotation=45)
plt.ylabel("Count")
plt.show()

# %%
plt.pie(Commute_counts, labels=Commute_counts.index, autopct='%1.1f%%')
plt.title("Primary Commute Method")
plt.show()

# %% [markdown]
# ## Average Nightly Sleep Hours Distribution

# %%
Sleep_hours_counts = df["How many hours of sleep do you get on an average night?"].value_counts()
plt.bar(Sleep_hours_counts.index, Sleep_hours_counts.values)
plt.title("Average Nightly Sleep Hours")
plt.xlabel("Hours")
plt.xticks(rotation=45)
plt.ylabel("Count")
plt.show()

# %%
plt.pie(Sleep_hours_counts, labels=Sleep_hours_counts.index, autopct='%1.1f%%')
plt.title("Average Nightly Sleep Hours")
plt.show()

# %% [markdown]
# ## Average Daily Water Intake Distribution

# %%
water_intake_counts = df["On average, how much water do you drink per day?"].value_counts()
plt.bar(water_intake_counts.index, water_intake_counts.values)
plt.title("Average Daily Water Intake")
plt.xlabel("Water Intake'")
plt.xticks(rotation=45)
plt.ylabel("Count")
plt.show()

# %%
plt.pie(water_intake_counts, labels=water_intake_counts.index, autopct='%1.1f%%')
plt.title("Average Daily Water Intake")
plt.show()

# %% [markdown]
# ## Preferred Current Events Source Distribution

# %%
source_counts = df["What is your preferred method for staying informed about current events?"].value_counts()
plt.bar(source_counts.index, source_counts.values)
plt.title("Preferred Current Events Source")
plt.xlabel("Source")
plt.xticks(rotation=45)
plt.ylabel("Count")
plt.show()

# %%
plt.pie(source_counts, labels=source_counts.index, autopct='%1.1f%%')
plt.title("Preferred Current Events Source")
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# To find relationships and insights within the dataset, let's perform some analyses and create visualizations that explore these aspects.

# %% [markdown]
# ## Age vs. Preferred Study Time

# %%
# Age vs. Preferred Study Time
plt.figure(figsize=(8, 5))

sns.countplot(x='What is your age?', hue='When do you prefer to study?', data=df)
plt.title('Age vs. Preferred Study Time')

plt.tight_layout()

# %% [markdown]
# ## Age vs. Exercise Frequency

# %%
# Age vs. Exercies
sns.countplot(x='What is your age?', hue='How often do you exercise in a week?', data=df)
plt.title('Age vs. Exercise')
plt.tight_layout()

# %% [markdown]
# ## Daily Screen Time vs. Age

# %%
#screen_time_categories = pd.CategoricalDtype(categories=["Less than 1 hour", "1-3 hours", "4-7 hours", "More than 7 hours"], ordered=True)
#df['Daily Screen Time (hours)'] = df['Daily Screen Time (hours)'].astype(screen_time_categories)

#exercise_categories = pd.CategoricalDtype(categories=["I do not exercise", "1-2 times", "3-4 times", "5-6 times", "Every day"], ordered=True)
#df['Exercise Frequency per Week'] = df['Exercise Frequency per Week'].astype(exercise_categories)


# Daily Screen Time vs. Exercise Frequency
sns.countplot(x='How many hours do you spend on screens daily? (including phone, laptop, tablets )', hue='What is your age?', data=df)
plt.title('Screen Time vs. Age')
plt.xticks(rotation=45)
plt.tight_layout()

# %% [markdown]
# ## Coffee or Tea Preference vs. Number of Languages Spoken

# %%
# Coffee or Tea Preference vs. Number of Languages Spoken
sns.countplot(x='How many languages do you speak fluently?', hue='Do you prefer coffee or tea?', data=df)
plt.title('Coffee or Tea Preference vs. Number of Languages Spoken')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Commute Method vs. Exercise Frequency

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='How do you primarily commute to work or school?', hue='How often do you exercise in a week?', data=df,width=0.6)
plt.title('Commute Method vs. Exercise Frequency')
plt.xlabel('Count')
plt.ylabel('Commute Method')
plt.legend(title='Exercise Frequency',fontsize='small')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sleep Hours vs. Daily Screen Time

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='How many hours of sleep do you get on an average night?', hue='How many hours do you spend on screens daily? (including phone, laptop, tablets )', data=df,width=0.7)
plt.title('Sleep Hours vs. Daily Screen Time')
plt.xlabel('Sleep Hours')
plt.ylabel('Count')
plt.legend(title='Screen Time', loc='upper right')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Plots:
#
#     - Bar Chart
#     - Pie Chart
#     - Countplot

# %% [markdown]
# *check* for matplotlib colors:
# https://matplotlib.org/stable/gallery/color/named_colors.html
