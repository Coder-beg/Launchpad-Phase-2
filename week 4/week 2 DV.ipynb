# %% [markdown]
# Reading Material: https://pypi.org/project/google-play-scraper/

# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in c:\users\maimo\anaconda3\lib\site-packages (1.2.4)
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\maimo\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\maimo\anaconda3\Lib\site-packages)

# %% [markdown]
# ## Information about app

# %%
from google_play_scraper import app

result = app(
    'com.facebook.katana',
    lang='en', # defaults to 'en'
    country='us' # defaults to 'us'
)
result
# Out:
# {'title': 'Facebook',
#  'description': 'Whether you’re looking for a spark of inspiration with reels or want to dive deeper into something you already love with Marketplace or in groups, you can discover ideas, experiences and people that fuel your interests and help you make progress on the things that matter to you on Facebook.\r\n\r\nExplore and expand your interests:\r\n* Shop for affordable and uncommon stuff on Marketplace and take your hobbies to the next level\r\n* Personalize your Feed to see more of what you like, less of what you don’t\r\n* Watch reels for quick entertainment that sparks inspiration\r\n* Discover creators, small businesses and communities who can help you dive deeper into the things you care about\r\n\r\nConnect with people and communities:\r\n* Join groups to learn tips and tricks from real people who’ve been there, done that\r\n* Catch up with friends, family and influencers through Feed and stories\r\n\r\nShare your world:\r\n* Effortlessly create reels from trending templates, or let your creativity shine with a full suite of editing tools\r\n* Customize your profile to choose how you show up and who you share your posts with\r\n* Turn your hobby into a side hustle by becoming a creator or selling things on Marketplace\r\n* Celebrate everyday, candid moments with stories, which disappear in 24 hours',
#  'descriptionHTML': 'Whether you’re looking for a spark of inspiration with reels or want to dive deeper into something you already love with Marketplace or in groups, you can discover ideas, experiences and people that fuel your interests and help you make progress on the things that matter to you on Facebook.<br><br>Explore and expand your interests:<br>* Shop for affordable and uncommon stuff on Marketplace and take your hobbies to the next level<br>* Personalize your Feed to see more of what you like, less of what you don’t<br>* Watch reels for quick entertainment that sparks inspiration<br>* Discover creators, small businesses and communities who can help you dive deeper into the things you care about<br><br>Connect with people and communities:<br>* Join groups to learn tips and tricks from real people who’ve been there, done that<br>* Catch up with friends, family and influencers through Feed and stories<br><br>Share your world:<br>* Effortlessly create reels from trending templates, or let your creativity shine with a full suite of editing tools<br>* Customize your profile to choose how you show up and who you share your posts with<br>* Turn your hobby into a side hustle by becoming a creator or selling things on Marketplace<br>* Celebrate everyday, candid moments with stories, which disappear in 24 hours',
#  'summary': 'Explore the things you love',
#  'installs': '5,000,000,000+',
#  'minInstalls': 5000000000,
#  'realInstalls': 9348137692,
#  'score': 3.6440678,
#  'ratings': 138951524,
#  'reviews': 4195490,
#  'histogram': [35795485, 5816578, 7878082, 12020970, 77440380],
#  'price': 0,
#  'free': True,
#  'currency': 'USD',
#  'sale': False,
#  'saleTime': None,
#  'originalPrice': None,
#  'saleText': None,
#  'offersIAP': True,
#  'inAppProductPrice': '$0.05 - $2,499.99 per item',
#  'developer': 'Meta Platforms, Inc.',
#  'developerId': 'Meta+Platforms,+Inc.',
#  'developerEmail': 'facebook.android@fb.com',
#  'developerWebsite': 'https://www.facebook.com/facebook',
#  'developerAddress': '1 Hacker Way\nMenlo Park, CA 94025',
#  'privacyPolicy': 'https://www.facebook.com/about/privacy/',
#  'genre': 'Social',
#  'genreId': 'SOCIAL',
#  'categories': [{'name': 'Social', 'id': 'SOCIAL'}],
#  'icon': 'https://play-lh.googleusercontent.com/KCMTYuiTrKom4Vyf0G4foetVOwhKWzNbHWumV73IXexAIy5TTgZipL52WTt8ICL-oIo',
#  'headerImage': 'https://play-lh.googleusercontent.com/IPiYhMAw_Y0WmQ7hpKkU_XE4QK5q9X_hECm649kDavLbVkSEnDGAjav_KisF3URVeHXu',
#  'screenshots': ['https://play-lh.googleusercontent.com/W_Y8ucZDrPOv9fBnDMF_s8y1e7NEsuw5_X3J3kE2dneQrzIB-K4Q4hv4bxcFuPnkhg',
#   'https://play-lh.googleusercontent.com/PTAbVSQOLpXQeVrzjQDNDUjPUp8C2Kr6PnO_Jh-p7s9eScuwZ4Y3x1U1W39rBeHieEg',
#   'https://play-lh.googleusercontent.com/xL67taOKGP0WLg28H6s3Jf2xDL3F4_Tj4O4a9Exs7u19muZFcFzuChk2zgMqec7umA',
#   'https://play-lh.googleusercontent.com/kvvzjEmtQU0wDB3hUHyBuu0N2QRshAWu3RBTKEPZOisYgGBa3P3UxU71rYzLPHcqals',
#   'https://play-lh.googleusercontent.com/xxpLCl7SsEBouBCJLLsvDaKP9cMszUysS2S7U0hWMX7PA0TkvCNjg-NAsE-h-IpkGysJ',
#   'https://play-lh.googleusercontent.com/uqHVgLS71SyODUBotnB2OK0TDq_BKOoH-wk-9mEQPFesR-ISotxUgYF7rdVk8vDkoNk'],
#  'video': None,
#  'videoImage': None,
#  'contentRating': 'Teen',
#  'contentRatingDescription': None,
#  'adSupported': True,
#  'containsAds': True,
#  'released': None,
#  'updated': 1708532061,
#  'version': None,
#  'comments': ['Ok app, if you can deal with constant reshuffling of the interface. Unfortunately, it can and will spam you with notifications. Even if you turn it off everywhere (countless locations), every few updates it still "grows" new ways to boggle you with unrelated content, like the Hydra. The "new" features tend to show up leading to the quarterly earning report. I know you\'re trying to keep up the engagement and numbers, but please try to do it in a more subtle way',
#   "I don't know what happened lately, but the performance of the application is giving a subpar experience to the point I'm considering uninstalling it. Also, my like icons are gone, and sometimes even the option to do a like is gone. Videos are also a terrible experience. They work like reels, which is horrible for longer videos, and having the video play over and over again while reading the comments just kills it for me. Is interesting seeing this many issues from such a big company.",
#   'After a recent update, my "like" options have completely disappeared. When I click to like something it shows a series of blank, white circles. It does the same when trying to see who has liked a pictures. It also glitches so bad. I can\'t even scroll through anything because it freezes and lags continuously. I\'ve tried to restart my phone, reinstall the app...nothing helps.',
#   "New, since Feb 13, when I click on mine or anyone else's cover photo, it's a blank screen. I can't view all my cover photos. It's not saying it needs an update. I see more stuff from pages I don't even follow, than those I do and even my FB friends. Show me the stuff from my friends and pages I actually FOLLOW! I am not even getting all notifications. WHAT THE HECK???",
#   "Video viewing is a horrendous experience on Facebook. They removed the scrub bar, so you can't go forward or rewind. Sometimes if you pause a video, it will restart at the beginning when you press play. Some videos will just pause randomly and either resume playing after skipping ahead, or just refuse to play past a certain point. Some videos will make you watch 1 or 2 ads in the middle, even if the video is only 30 seconds long. You can't even see comments without being redirected to Instagram.",
#   "I would like to see options for Best Friends. And font options and stylization like italics and bold. These options make it so much more personal and streamlined. I might just be so overwhelmed and drained with social media I've seriously considered taking a break and just reading a real book. Taking a walk. Safety and Mental issues are not emphasized enough. Aside from the obvious, like setting your screen to night or sleep mode to protect your eyes and that prevent you from falling asleep.",
#   'I no longer have friends show on my news feed, it is all pages that "the Facebook app thinks I would like " I x them one by one but more pages pop up filling the space including the pages I clicked on the "don\'t see this page again " come back around. I also have Facebook set for manual updates instead of automatic but it keeps updating on its own. I agree with others who say that Facebook has gotten stupid.',
#   "Fix your worthless app and fire your worthless devs. The gallery will no longer display more than the 30 oldest photos/videos in any album. No matter how much you try to scroll, anything newer then the first 30 are completely inaccessible. An example, I go to look and change my profile picture. My profile pic album has 100 photos in it, but the only ones I'm allowed to see or select are back from 2014 to 2016.",
#   'For the last month, all videos are opening in the " reel" format, and it\'s frustrating! I\'ve done all the tech support things like clearing cache, uninstalling, and reinstall etc and nothing has helped. I\'ve emailed multiple emails for Facebook as there is no longer support on the app. The support tab now is all just articles they wrote, so you can\'t get help anymore. This is ridiculous.',
#   "frustrated I don't get a lot of my notifications for things like replies and end up seeing the reply later and still don't have any notifications, also on reels and videos the reply comments won't load, a lot of the time the videos won't flip on my phone, not the reels just to clarify, I'm talking about wide videos. These problems have been going on for a few years now and I've seen troubleshoots and reports and it.. never stops. so yeah getting frustrating",
#   "Whatever you're doing, stop it. Every update makes things more complicated. I have to sign in and out of my pages/profiles. Currently cannot get out of messenger that i accessed thru the FB app, it just takes me in circles and the only option out is to create a new account. Currently can't access anything else. App is up to date.",
#   "This app sucks! It literally does not work. I went to switch between messenger and fb and it just loaded.....then I refreshed the app and still just loading....When I went to search a name in fb it just doesn't even load....worse app I've ever used. You can't even use it because it doesn't even load!!!! Many problems every time I use it - so slow, won't load, when you go to your friends list it just glitches out and sends you the too every time so you can't even look a friends at the bottom.",
#   "It has been an astonishing tool of connectivity. However, its totalitarian behavior and obvious political bias have made it an insufferable experience. Now, it's loaded with ads that I don't want to see, and the 'show less' option doesn't do a damn thing. Would glady leave this platform if only there were something to replace it with.",
#   "Review of FB Dating: First, I got multiple errors when trying to save profile details. The app will also not upload photos from your saved albums, just gallery, camera roll and screenshots. It also crashed/froze three times while swiping. If you swipe, button inputs will stop working. On top of that, 90% of the people I see are over 100 miles away and I live in a major city! All in all, it's a broken, under baked feature that feels like an afterthought instead of a standalone dating app.",
#   "Whenever I press the navigation button to view my open apps, the Facebook window is suddenly not there. If I try to reopen it, it goes immediately to wherever I was -- so it obviously didn't close. So why does it disappear every time? This has been an intermittent issue that changes with various updates -- after some updates, it doesn't close the window anymore. And then other updates, it does that again. PLEASE FIX THIS!",
#   'There must have been a recent update, because now all of my "like" options have disappeared just showing white circles. I can\'t react to anything other than a simple "like" and I can\'t see what other people have reacted. And the screen is lagging like crazy. I thought it was fixed last night, it was perfectly fine. But now it\'s back to the white circles and lagging. That coupled with the constant onslaught of ads is just making me stay off Facebook.',
#   "Terrible UI/UX design. There is no way that any developer work a grain of salt would be okay with releasing garbage like this. If I save a video, I don't want to watch that short from the exact second I left off. This isn't Netflix, these are 15-30 second videos, and you're so bad at your job, you can't figure out how to make them restart, so they just replay from the same middle area, every time. Go get a real job.",
#   "Second edit: seriously, still an issue. The back button still doesn't close the app anymore. Edit: Cool, so instead of fixing the existing back button issue, you actually just made it work even less than it did before. Thanks a lot. When I press the back button, I want to EXIT THE APP. I don't want you to scroll to the top and load more garbage to waste my time on. I used to just shrug it off, but recently, spamming the back button no longer (eventually) closes it; it just stays open.",
#   "The only problem that I have is the live function. It doesn't rotate like it should. I'm a musician going live at every event that I play and when I go live, normally, the entire screen rotates to landscape. Currently, I still record landscape, but when I want to rewatch the footage, I have to turn off auto rotation on my phone and I despise doing that.",
#   "My Facebook said it needed to update. I don't normally have problems with Facebook updating so I did update it. Now, I'm having trouble even getting the app to open! And when it does finally open, I can't see my news feed, or my notifications, or anything! Great! Now I can't even scroll through my groups anymore! What the heck, Facebook? I'm about ready to delete this app",
#   "Edit: The update disabled the multiple pictures on the regular news feed and moved to to my personal time-line. They always have to screw things up! This last update has caused a problem with uploading multiple pictures in one post. Didn't have any issues until it updated. And I tried uninstalling it, but it forces you to update before you can get back into it. The pictures go to my story but doesn't actually post to my time line.",
#   "I like the app overall even though it keeps updating all the time but my main issue is you can't share your listings from the Marketplace into other groups. It has been an option from time to time but it's pretty annoying for people who sell a bunch of stuff on Facebook Marketplace. There have been issues that come and go but they are quickly fixed, typically I just check if it needs to be updated when I have an issue and it needs to be updated.",
#   'Did someone buy Facebook, or is Mark bored and wanting to mess with people!? The constant changes are horrible. If they actually made changes that were improvements to the platform, I would be happy with them, but so far, they are not helpful. Also, the increased amount of ads and sponsored sites cluttering your feed is absolutely ridiculous! No matter what features you turn off in settings for every post you see from a friend, you see three or more of these ads or sponsors!',
#   "Facebook changed in so many ways and it not for the better it gets dumber every day. For sample, the news feed u see something and you want to view the comments and it shows most relevant by default and your having to keep clicking show all, this is so dumb. the app keeps crashing, overloading your phone forcing it to shut down and protect it self from Facebook. don't get me started on the scams and the video that are not appropriate.",
#   "Still only deserves one star. So much of what I see is ads and pages that Facebook thinks I might want to follow. Also, the account options are confusing and constantly changing, so good luck ever finding anything. The follow option seems to be quite broken too. I don't always get notifications for people that I have chosen to follow, but I get plenty of notifications for people that I liked one post by. It's just a mess of an app in terms of functionality.",
#   "Whenever going to messenger and then trying to go back to the app., it just kicks me back to my home screen. Clicking on the Facebook app again just takes me to messenger. I have to completely close out of the app. and refresh each time this happens to be able to get Facebook up again. I've cleared caches and everything, it still hasn't fixed the issue. They need to fix this bug.",
#   'Ive been a member of facebook for a REALLY long time, and have had nothing but mostly good experiences. However, this latest update is pure rage fuel. Every time I put the app in the background even for a split second, it takes me back to the top of my feed. If I open a reel to watch it, I cant back out of it without it going to the top of my feed and then I lose the rest of the reels, or have to scroll endlessly to get back to them. This "feature" has GOT to go.',
#   "I can say for the most part I experienced good service, met a lot of interesting people and learned technical skills in the mean time. My problems that I endure are I can never retrieve lost texts or messages that will disappear in the middle of me writing the sentence. I don't know where to address the issue, or what Google device or app I should look into. Very confusing.",
#   'The new updates have made this app completely unusable for me. I upload photos in albums to share with friends and family. Unfortunately, FB no longer loads the posts properly (and ANY posts beyond those) on my feed when an album with more than 100 photos exists. Consequently, it also breaks my notifications. The thing is, an older version of the app solves the issue for me, which means that they messed something up on one of the recent updates but have no desire to fix it.',
#   'Links will no longer open from the FB feed. (They will open from Messenger.) I\'ve looked through all Settings. I\'ve searched for solutions, & none helped. Links will still not open within FB, or in an external browser. Sometimes it\'s like a new white window slides in from the right. But, it immediately goes away. There\'s no option to copy the links either. ● Why can\'t you dismiss the "live" notifications while watching Reels videos? There\'s always a "* is live" message in the way.',
#   "The filters are not sortable when you are going live. Just like thousands of filters to go through. I'd like to have a simple background effect to use with my phone while going live. Like maybe a library background scene, or just a black background scene. Not a bunch of sponsored stuff that is in all kinds of different languages and all the silly ones. Can't you make them sortable?",
#   "App constantly crashes, then won't open again. Sometimes won't play sounds on videos, it will only load 2 seconds of video before it will refuse to play. Also hijacks my phone when it crashes, not allowing me to access any screens or other apps, forcing me to restart my phone. And the newest thing now is I can't access marketplace, and I've got no explanation as to why. Overall, the quality of Facebook has been on a steady decline. Deleting profile and app.",
#   "They refuse to delete fake accounts impersonating people. They literally send a notification saying they did nothing and don't see it as wrong, despite having the built-in option to report impersonation and fake accounts. The app is also not usable in landscape mode. If you open the app in landscape, it switches to portraits and locks it that way. These are only my most recent issues. Tip of the iceberg. Absolutely appalling app in every way. They won't fix decade-old bugs with constant new bugs",
#   "The feature to open links from the app directly in an external browser, like Chrome or Firefox is broken. The user is forced to use the app's built-in browser, after clicking a link, which violates user privacy. It would be a different problem if the setting didn't exist, but the setting does exist and it tricks the user into believing they have control over their privacy. This is a dark pattern.",
#   "Hadn't really had many problems except for these TWO URKING issues. One issue is that it will tell me I have notifications when I log in, and when I click on the notification bell, it shows me nothing new until I refresh the page. Next issue is that when I'm watching reels, I'll watch video #1, scroll and then video #2, and then video #1 will come up again and so will video #2. It does this the whole time I try to watch reels and it's getting old!",
#   'Nope! Hate all of it. Latest update has made my friends list scattered. I LIKE IT ALPHABETICAL, not random. There is no option to change it either. I am so sick of the bombardment of random "You might like this" stuff on my page. Facebook has become too intrusive in my opinion. I have backed off of using it the last 2 years and am getting to the point of deleting it altogether. The more you try to make it better, the worse you make it 😡',
#   "I noticed this morning, that my folder of profile pictures and cover photos, only shows pictures of over 10 years old. I updated the app, and that didn't help. The number of pictures listed that are in the folders, are much more than what is showing up. The pictures all show up when I log into a browser.",
#   "The only gripe I have is with Facebook LIVE. It will not allow me to switch to landscape. I've tried changing settings and all. When I try to connect while in landscape, a message appears saying Landscape is not supported. However, if I uninstall Facebook and then doawload it again, then it will allow me to record in landscape (one time). Please fix this.",
#   'App doesnt care about UX as long as they are getting clicks and ad views. Theres a whole segment of the population that uses FB almost exclusively for Marketplace. You wiuld think that for an app thats been in development for over a decade that they would have ironed out the bugs by now. Unfortunately, Marketplace is still horrible to use, and hardly works as intended, particularly on mobile devices. The filter features and search regions do not work, and making a car listing is heinously bugged',
#   'I\'m getting videos that are in foreign languages that I don\'t understand. It\'s not even languages close to English either. They are all Middle Eastern and Asian languages. I keep selecting "show less," but it doesn\'t work. It\'s been doing this for weeks now, and it\'s really annoying that I can\'t find a video to watch without clearing tons of foreign language videos. After that, I might get a few in English, but then it reverts back again. And can reels stop hijacking my screen brightness?'],
#  'appId': 'com.facebook.katana',
#  'url': 'https://play.google.com/store/apps/details?id=com.facebook.katana&hl=en&gl=us'}

# %%
result.keys()
# Out:
# dict_keys(['title', 'description', 'descriptionHTML', 'summary', 'installs', 'minInstalls', 'realInstalls', 'score', 'ratings', 'reviews', 'histogram', 'price', 'free', 'currency', 'sale', 'saleTime', 'originalPrice', 'saleText', 'offersIAP', 'inAppProductPrice', 'developer', 'developerId', 'developerEmail', 'developerWebsite', 'developerAddress', 'privacyPolicy', 'genre', 'genreId', 'categories', 'icon', 'headerImage', 'screenshots', 'video', 'videoImage', 'contentRating', 'contentRatingDescription', 'adSupported', 'containsAds', 'released', 'updated', 'version', 'comments', 'appId', 'url'])

# %% [markdown]
# Let's break down the key information in the provided data for the Facebook app:
#
# 1. **title**: 'Facebook'
#    - The name of the app.
#
# 2. **description**:
#    - A detailed overview of the features and functionalities of the Facebook app. It covers aspects like inspiration with reels, exploring interests, connecting with people and communities, sharing content, and more.
#
# 3. **summary**: 'Explore the things you love'
#    - A concise summary or tagline describing the primary purpose or theme of the app.
#
# 4. **installs**: '5,000,000,000+'
#    - The number of installations reported on Google Play. In this case, it's 5 billion or more.
#
# 5. **minInstalls**: 5000000000
#    - The minimum number of installs, which matches the provided 'installs' value.
#
# 6. **realInstalls**: 9348137692
#    - The actual or real number of installs, which may be different from the reported installs on Google Play.
#
# 7. **score**: 3.6440632
#    - The average user rating of the app, which is approximately 3.64.
#
# 8. **ratings**: 138951582
#    - The total number of user ratings received by the app.
#
# 9. **reviews**: 4195476
#    - The total number of user reviews available for the app.
#
# 10. **histogram**: [35795633, 5816559, 7878190, 12020927, 77440244]
#    - A histogram of user ratings, indicating the distribution of ratings in different categories (1 star, 2 stars, etc.).
#
# 11. **price**: 0
#     - The price of the app. In this case, it's free.
#
# 12. **free**: True
#     - A boolean value indicating whether the app is free or not.
#
# 13. **currency**: 'USD'
#     - The currency in which the price is denominated.
#
# 14. **sale**: False
#     - A boolean value indicating whether the app is currently on sale.
#
# 15. **offersIAP**: True
#     - A boolean value indicating whether the app offers in-app purchases.
#
# 16. **inAppProductPrice**: '$0.05 - $2,499.99 per item'
#     - The range of prices for in-app products available within the app.
#
# 17. **developer**: 'Meta Platforms, Inc.'
#     - The name of the developer or the company behind the app.
#
# 18. **developerId**: 'Meta+Platforms,+Inc.'
#     - An identifier for the developer.
#
# 19. **developerEmail**: 'facebook.android@fb.com'
#     - The contact email address for the developer.
#
# 20. **developerWebsite**: 'https://www.facebook.com/facebook'
#     - The official website of the developer.
#
# 21. **developerAddress**: '1 Hacker Way\nMenlo Park, CA 94025'
#     - The address of the developer.
#
# 22. **privacyPolicy**: 'https://www.facebook.com/about/privacy/'
#     - The link to the privacy policy of the app.
#
# 23. **genre**: 'Social'
#     - The genre or category of the app.
#
# 24. **genreId**: 'SOCIAL'
#     - An identifier for the app's genre.
#
# 25. **categories**: [{'name': 'Productivity', 'id': 'PRODUCTIVITY'}]
#     - A list of categories to which the app belongs. In this case, it is under the 'Productivity' category.
#
# 26. **icon**: 'https://play-lh.googleusercontent.com/...'
#     - The URL to the app's icon.
#
# 27. **headerImage**: 'https://play-lh.googleusercontent.com/...'
#     - The URL to the app's header image.
#
# 28. **screenshots**: [list of URLs]
#     - A list of URLs to screenshots showcasing the app.
#
# 29. **video**: None
#     - The URL or information about a promotional video for the app.
#
# 30. **videoImage**: None
#     - The URL to an image related to the promotional video.
#
# 31. **contentRating**: 'Teen'
#     - The content rating assigned to the app.
#
# 32. **adSupported**: True
#     - A boolean value indicating whether the app contains ads.
#
# 33. **containsAds**: True
#     - A boolean value indicating whether the app contains ads.
#
# 34. **released**: None
#     - The release date of the app.
#
# 35. **updated**: 1708532061
#     - The timestamp of the last app update.
#
# 36. **version**: None
#     - The current version of the app.
#
# 37. **comments**: [list of user comments]
#     - A list of user comments or reviews about the app.
#
# 38. **appId**: 'com.facebook.katana'
#     - The unique identifier for the app on the Google Play Store.
#
# 39. **url**: 'https://play.google.com/store/apps/details?id=com.facebook.katana&hl=en&gl=us'
#     - The URL to the app on the Google Play Store.

# %% [markdown]
# ## Get the data of same category apps

# %%
import google_play_scraper
from google_play_scraper import *

# %%
result = search("games", lang="en", country="pk")
result
# Out:
# [{'appId': 'com.kiloo.subwaysurf',
#   'icon': 'https://play-lh.googleusercontent.com/7vaSXksRUQvWPCFuItT268rZIBEJxXrW-q2B46tLyVqA-_0eux8xKLU2zmjKvlhLGU4',
#   'screenshots': ['https://play-lh.googleusercontent.com/50vhMPdggicC3Hi8iHMXbRA_x-XWCyrwfI3p9To8mh3sygiiszfMCWeKCHdU6hqFFFk3',
#    'https://play-lh.googleusercontent.com/TuXvYDNUCxTZxDNjD8Qfhfcd66F_p97GpXwnPXdIIiiKgqegeWIGhgt3DdCnxowyJJk',
#    'https://play-lh.googleusercontent.com/_VDeaz1efC7kBQyOH9tjnYuiTRJP9Z03GDOFsUpU8uk5K313xQP3zc6GhuSqF5d3khI',
#    'https://play-lh.googleusercontent.com/qozyVCwKvA6gdpabh2B5g6t4SvH7Yvfs80MIfO7hXMTg_2hhes1z7JpUyXFtdQhKa6U',
#    'https://play-lh.googleusercontent.com/C_n6fAXQWPdrUNbR9FKrpOD9HvAqNHmhHpzop8pTxHnNvvrmHmBFHiVncxG-8Ig-hg',
#    'https://play-lh.googleusercontent.com/dH5Mf9b7_YKtSTPNusE0R3ozGdfSJiLIVSDG-uD80HxRiYdSsiEpstIdA56sMArxJbo',
#    'https://play-lh.googleusercontent.com/gd3w8qo4F6xy8xsQ2auUPVT0bDUFZTdzJnB_aM-pGVDNKbN5RniLAi5duzo6nhdQhXA',
#   'free': True,
#   'currency': 'PKR',
#   'video': 'https://www.youtube.com/embed/XKbvYmkxhVk?ps=play&vq=large&rel=0&autohide=1&showinfo=0',
#   'videoImage': 'https://i.ytimg.com/vi/XKbvYmkxhVk/hqdefault.jpg',
#   'description': 'DASH as fast as you can! \r\nDODGE the oncoming trains! \r\n\r\nHelp Jake, Tricky & Fresh escape from the grumpy Inspector and his dog. \r\n\r\n★ Grind trains with your cool crew! \r\n★ Colorful and vivid HD graphics! \r\n★ Hoverboard Surfing! \r\n★ Paint powered jetpack! \r\n★ Lightning fast swipe acrobatics! \r\n★ Challenge and help your friends! \r\n\r\nJoin the most daring chase! \r\n\r\nA Universal App with HD optimized graphics.\r\n\r\nOriginally co-developed by SYBO and Kiloo.',
#   'descriptionHTML': 'DASH as fast as you can! <br>DODGE the oncoming trains! <br><br>Help Jake, Tricky &amp; Fresh escape from the grumpy Inspector and his dog. <br><br>★ Grind trains with your cool crew! <br>★ Colorful and vivid HD graphics! <br>★ Hoverboard Surfing! <br>★ Paint powered jetpack! <br>★ Lightning fast swipe acrobatics! <br>★ Challenge and help your friends! <br><br>Join the most daring chase! <br><br>A Universal App with HD optimized graphics.<br><br>Originally co-developed by SYBO and Kiloo.',
#   'developer': 'SYBO Games',
#   'installs': '1,000,000,000+'},
#  {'appId': 'com.fingersoft.hillclimb',
#   'icon': 'https://play-lh.googleusercontent.com/N0UxhBVUmx8s7y3F7Kqre2AcpXyPDKAp8nHjiPPoOONc_sfugHCYMjBpbUKCMlK_XUs',
#   'screenshots': ['https://play-lh.googleusercontent.com/6oapIRmqsbr-yt_tBZVvs-ollGW_kw5SpuHFOTA9gbQzZ5rteDyQX0BrK2upnmGYeBs',
#    'https://play-lh.googleusercontent.com/DqkuuSvPP-48Bc6TtxONVQBhXwJu2xtD958VLi4_MGNUwXiYZG1WDg3Y333TzB6ifw',
#    'https://play-lh.googleusercontent.com/x5Em7OrFJPW1cWCt0sim-P_H-94dNnIazuXtRY1xXNEJ1qDEKYPfHjlzWy09HArjSVw',
#    'https://play-lh.googleusercontent.com/FWM1kX5IO_4JaU1fHCyaS-ViSIZLRf6CfD3ab5zGMvq4iB11jhuCg5X0c1jT1i0W17Y',
#    'https://play-lh.googleusercontent.com/vRkyNkMCoch7TBoGF7OhX2Zj1l5jV_pEB-xAWf_W50D2LiBFdl3RZMI78Ny47h7G0Kk',
#    'https://play-lh.googleusercontent.com/yfVwOyVT5gsQdZBABB3idTVIkmT7n50PlJGJAix3TsV1V4bXpMEOcwAfBjlIdz8WWaOy',
#    'https://play-lh.googleusercontent.com/ConmtKKQkI4nQLYNFz1NzfzlDhiXGYlgFC2Tzu37NiaCdJzoemsezo-21a3A86JYmw',
#    'https://play-lh.googleusercontent.com/rb-9OS6KLAEoroYdQHFJEvNdeAd46kEetauG9Im7IfUhzR62v-mu_7Mhg0UYgsu7S94',
#    'https://play-lh.googleusercontent.com/bnGmzL0DIA6j3p2RB70su9rg4-hlPdXxoIymxNRaU0HmwxMMfZ2yHwg2jL9GSV55wuoD',
#    'https://play-lh.googleusercontent.com/2o2ZannodhclwxvlxqTyh2_zGPhxVR-NAbpthh53GWg0gJJ6eIK-t-ljOy6BZK03mYM',
#    'https://play-lh.googleusercontent.com/CmnxMglUB5A8lNi1dRvcOf_ZhN5TQ0i8cMp-wXEYQj9WnY1ceZshADarqwAMRE_f0J0',
#    'https://play-lh.googleusercontent.com/pV_nYnmZIPmFMDY1XpTsq3K9gXQ44fYEutZ2ZQvUWWYo4ZdPHTNIIQAtE2TJZ5LirX4',
#    'https://play-lh.googleusercontent.com/DlOvw4e3czYFsJkWV6O6_evgwm_PAftuAeSF9PvxTgNH6J7pQdBMpGARcGapfkN72h3j',
#    'https://play-lh.googleusercontent.com/dL1bZQPzae-ANkZIs4Yjuv54oYZwEOyUvIb-bdy3Hi6Q4-Ba_Y44i_cfQ_7WacW8_IQ',
#    'https://play-lh.googleusercontent.com/pNFmLZIvtt6CVRt-BUkIPNNyiTnH23keDPMCBWWIsKx4dpSLXwk5LBTz9_J0lPo-_g',
#    'https://play-lh.googleusercontent.com/uR7DQRd2-n19yXDTwnZzHffYJu0K81vJrpVH5jUZBYM314v_XlV9sk4kqxpIFPpMukg',
#    'https://play-lh.googleusercontent.com/3JSrldQDaH4L6XfdTfSosjzbcl8q9wqUqPmq45OJC8_80cp7PmrBnWBVFhFDmdWcWiA',
#    'https://play-lh.googleusercontent.com/D1JCPkO_Pf7yYMhI5fJAVASCpK3idzBWnnl-2VQ_R5OEmQLe_rvquMalFZWHYz2qBVw',
#    'https://play-lh.googleusercontent.com/E2KGVPaP0jn4J--gp3x0QSR4BRyHqJ-AOqSwYbS16vka9EpQa7k1rO4xqkbIZDBikg'],
#   'title': 'Hill Climb Racing',
#   'score': 4.11595,
#   'genre': 'Racing',
#   'price': 0,
#   'free': True,
#   'currency': 'PKR',
#   'video': None,
#   'videoImage': None,
#   'description': "Play the original classic Hill Climb Racing! Race your way uphill in this physics based driving game, playable offline!\r\n\r\nMeet Bill, the young aspiring uphill racer. He is about to embark on a journey through Climb Canyon that takes him to where no ride has ever been before. With little respect to the laws of physics, Bill will not rest until he has conquered the highest hills up on the moon!\r\n\r\nFace challenges in unique hill climbing environments with a wide variety of cars to choose from. Earn points from daring tricks and collect coins to upgrade your car and travel further distances. Watch out though - Bill's neck is not what it used to be when he was a kid! And his good old gasoline crematorium will easily run out of fuel.\r\n\r\nFeatures::\r\n\r\nFresh Content\r\nWe are still actively developing Hill Climb Racing and adding new vehicles, new stages and new content! \r\n\r\nUnique Vehicles\r\nGet behind the wheel of a wide variety of different vehicles. From the iconic Hill Climber to bikes, race cars, trucks and even some outlandish vehicles such as the creepy Carantula! Half car, half tarantula, do you dare drive it?\r\n\r\nPlay Offline\r\nRace offline whenever and wherever you want! Hill Climb Racing is playable completely offline. Play it on a bus, plane or train! Play it anywhere!\r\n\r\nWacky Stages\r\nClimb Canyon is full of unique challenges and stages for you to overcome with vastly different terrains and hazards. How far can you drive without running out of gas or crashing your vehicle?\r\n\r\nUnlock and Upgrade\r\nTune up and fix your dream vehicle with cust
#    'https://play-lh.googleusercontent.com/LnMpHVPf2LkFGR5jkRavFKlNfcaqd-SgUOprF37YtsAJaQsaxag3Hj62y-L8Mpl2hqE',
#    'https://play-lh.googleusercontent.com/_YgGDGn-Oyu85sp3XJgCjoaOF-QMF2-Lrnyi7zWZCrjILLhYjk8wtLrdmYhZPyHHuw',
#    'https://play-lh.googleusercontent.com/7WCjgF9DhMaTP-4IlbGByktmqn3qYE9AQsRzxm8oDroIDmK8l-w5as83MXiLRa4aloQ',
#    'https://play-lh.googleusercontent.com/Co22rDGvYSC0YVG8mG5gzppnydahX5jVdJOscQ2OhQAbvqh_kdmXbV6OSF9GvM-MjdQm',
#    'https://play-lh.googleusercontent.com/4gmf-n2YUIeX3gjwvkCLluoTRcN9JbixqsDNf9FlmnB2OvFs0RIXEzyY04IHrUMVKBLg',
#    'https://play-lh.googleusercontent.com/uR3eSGOD5mxJx7gzWbKXAyNNzNKb9X5F7O8X-TZcUiZYIbgDCSWIgKpCGmDCLVzXz8TX',
#    'https://play-lh.googleusercontent.com/t7VoN8Ye0gEa3fW6c4vppsTYqFxSagOyxnG8Q92NlTrmOb2rXP3mJP6sZj7JXH7i9Q',
#    'https://play-lh.googleusercontent.com/SzZKd7e8AyzfhPY5Yy8HWJY66XHxTCxeVBJVWjZTlkMvnpbh_9WYwy5DL2TLXIga_AUe'],
#   'title': 'Temple Run',
#   'score': 4.0995746,
#   'genre': 'Arcade',
#   'price': 0,
#   'free': True,
#   'currency': 'PKR',
#   'video': 'https://www.youtube.com/embed/Mfjv3SfZdn4?ps=play&vq=large&rel=0&autohide=1&showinfo=0',
#   'videoImage': 'https://i.ytimg.com/vi/Mfjv3SfZdn4/hqdefault.jpg',
#   'description': 'Experience the thrill of Temple Run, now available on Android! \r\n\r\nJoin the global phenomenon and outpace your friends\' top scores!\r\n\r\nEmbark on a heart-pounding adventure as you flee with the stolen idol from the clutches of sinister Demon Monkeys. Sharpen your reflexes in a high-stakes sprint down the corridors of ancient temples and precarious cliff edges. Navigate with intuitive swipes: leap over gaps, dodge obstacles, and slide under hazards. \r\n\r\nAccumulate coins to acquire power-ups, unlock diverse characters, and push your limits to see the distance you can cover!\r\n\r\n"In every treasure hunting adventure movie there’s one scene in which the plucky hero finally gets his hands on the treasure but then has to navigate a maze of booby traps in order to get out alive. Temple Run is this scene and nothing else. And it’s amazing." - SlideToPlay.com\r\n\r\n\r\nREVIEWS\r\n\r\n★ "Most thrilling and fun running game in a while, possibly ever." - TheAppera.com\r\n\r\n★ "A fast and frenzied experience." - IGN.com\r\n\r\n★ "Very addicting… definitely a very different running game." - Appolicious.com\r\n\r\n★ Voted by TouchArcade Forums as Game of the Week\r\n\r\n★ One of TouchArcade\'s Best Games of the Month\r\n\r\n★ Over 50 MILLION players worldwide!',
#   'descriptionHTML': 'Experience the thrill of Temple Run, now available on Android! <br><br>Join the global phenomenon and outpace your friends&#39; top scores!<br><br>Embark on a heart-pounding adventure as you flee with the stolen idol from the clutches of sinister Demon Monkeys. Sharpen your reflexes in a high-stakes sprint down the corridors of ancient temples and precarious cliff edges. Navigate with intuitive swipes: leap over gaps, dodge obstacles, and slide under hazards. <br><br>Accumulate coins to acquire power-ups, unlock diverse characters, and push your limits to see the distance you can cover!<br><br>&quot;In every treasure hunting adventure movie there’s one scene in which the plucky hero finally gets his hands on the treasure but then has to navigate a maze of booby traps in order to get out alive. Temple Run is this scene and nothing else. And it’s amazing.&quot; - SlideToPlay.com<br><br><br>REVIEWS<br><br>★ &quot;Most thrilling and fun running game in a while, possibly ever.&quot; - TheAppera.com<br><br>★ &quot;A fast and frenzied experience.&quot; - IGN.com<br><br>★ &quot;Very addicting… definitely a very different running game.&quot; - Appolicious.com<br><br>★ Voted by TouchArcade Forums as Game of the Week<br><br>★ One of TouchArcade&#39;s Best Games of the Month<br><br>★ Over 50 MILLION players worldwide!',
#   'developer': 'Imangi Studios',
#   'installs': '500,000,000+'},
#  {'appId': 'com.miniclip.eightballpool',
#   'icon': 'https://play-lh.googleusercontent.com/cpGPqdXaVKMWzLJyyqwxaNoAFZONvTLccfrjCLibhIqJMnaVSA91VFg5oVj3EvDrMWg',
#   'screenshots': ['https://play-lh.googleusercontent.com/n0gbSN2iaVkXgnL8jxzfyDrXh0asjK23lCFEkBGwAKnPDp1gVFoBCi3-64LQf2nFZJI',
#    'https://play-lh.googleusercontent.com/Tk74gW7KxYnVdTUSrvllmkn_vDh2pDNgftnQJZULo8k8zAP_QKODw-eGlqCaubRnIsk',
#    'https://play-lh.googleusercontent.com/rGl0hx6dWKVYq9_YHcaaSLOGhkEy0kboyJ0X8reaHazDVi0o2bXVL2wJxt-keX984tk',
#    'https://play-lh.googleusercontent.com/RPPYYiM97go96PMjzxgUWVT_r1M0hCZe4xlx99tNxS26tkSDUKZH6-uPubPFHWlN3jbF',
#    'https://play-lh.googleusercontent.com/L7PaaGMtQVWTxxOtMpoy_vhmH3YdliH_P92wc2rv5Dkkc3DBiIa4RgmWiNL_ftoRKg',
#    'https://play-lh.googleusercontent.com/QrvVYxaxegHXwNi0MtZtUNrTYpkTzXYS1P1570iX5fRSsAaxxXVR13VribuiIQQLNcU',
#    'https://play-lh.googleusercontent.com/CnxpQjX_EVu4uO9pgCxrezI3hlvgU2oqnbbXbbEhdlVtxBJa6Ajajdeg5ov6mHjDcf0',
#    'https://play-lh.googleusercontent.com/kCs_MeVaDMSMgCwhAqMbjzcw0gqbrO3EjyXcwyJDKSZkj3JotWh1JLoVKJv5sUYKrT4',
#    'https://play-lh.googleusercontent.com/TmzBt3Dsu1jm2dRRFEzWY3Xj2ZDyHHHZUlhC8-4AgiBpi_w3Ssg9GjkDQYrYYqk-OnQ',
#    'https://play-lh.googleusercontent.com/s7DQo9qutOJawVgm9hwzukoWIGWmMRw3Ti3U5Vqby_NtITHY651av1tRMtnGMpXAyDym',
#    'https://play-lh.googleusercontent.com/5szRlfX5EKdfh32KiZz0W2Ck-I8-5IfLIaazGT4ObFlIhGlQjVTIpmJzwdvS1szrrNw',
#    'https://play-lh.googleusercontent.com/-6psnPbfxvmU52vCQ1-7cxb5lOSwf3O_JvTmdN3CDq3UFpE2Cc6GqxbkwMERgwwTxIg',
#    'https://play-lh.googleusercontent.com/_aL0mxNmipy1SqniSnTv49kSuqjGNS97ipl1_GEV6viYSUz4xI2lmkf1jdileIUJiQ',
#    'https://play-lh.googleusercontent.com/yNBgRtAC2nYeND8X1SzS77lFBqW6pw3zagP8VH964UJMmDmxbAgRzEUBX2_bZLxFIdA',
#    'https://play-lh.googleusercontent.com/8rJU50jVTt_0f9CCcmU7_gNZPqIhNbAFRBxm7-Qebt3GQWfvoaMDHxyco2-DpYbdQBez',
#    'https://play-lh.googleusercontent.com/PbvXaRdFKqwDqyFrZYvb4ZxHU_pgWZvP6g1-kIk-Akic1WDxFCLAgi9l8RixUk9JaA',
#    'https://play-lh.googleusercontent.com/2ahCaDHCeFLRGPPpvvGj_kick4rspvX5QlzWjLOaNOCnG1bLrX7fctvjtUoRBR7jnw',
#    'https://play-lh.googleusercontent.com/UMcIiN1ljoMTA7-hAPPQFaZa4BBUEAuWAoTKwp1pWP42p7B-U7VtL6xz4pE_z6Uux9g',
#    'https://play-lh.googleusercontent.com/jhg3zf4B6L9tQ5S4cimj7N4j5zsi0D3Ce89-o7ictK1sNV0b7bDBp-ZYcw1VfIvYjMo',
#    'https://play-lh.googleusercontent.com/U7hrXYcrQ9R162nyHaalBnq9VDSr99ataqDdNmn48_dgtQ0b4XmhjamHwMcX3ZRclA',
#    'https://play-lh.googleusercontent.com/Lk2o7MuLS8nJqY-3BDaKiPHbrzCBU7NRXWv--RqzveYl-Qq6Rus_qpV4LS2KkqttaEU',
#    'https://play-lh.googleusercontent.com/OOM2vj39CHFdfY1q6MO_uyZ-TpUbcQI5FnJ00k4w2mieqC5ke6vgSsy24XJrHv4xqK7A'],
#   'title': '8 Ball Pool',
#   'score': 4.3966694,
#   'genre': 'Sports',
#   'price': 0,
#   'free': True,
#   'currency': 'PKR',
#   'video': 'https://www.youtube.com/embed/_B7YwHCtCYA?ps=play&vq=large&rel=0&autohide=1&showinfo=0',
#   'videoImage': 'https://i.ytimg.com/vi/_B7YwHCtCYA/hqdefault.jpg',
#   'description': 'Play with friends! Play with Legends. Play the hit Miniclip 8 Ball Pool game on your mobile and become the best player!\r\n\r\n<b>COMPETE 1-ON-1 OR IN 8 PLAYER TOURNAMENTS<b></b>\r\n\r\nRefine your skills in the practice arena, take on the world in 1-vs-1 matches, or enter tournaments to win trophies and exclusive cues! \r\n\r\nPLAY FOR POOL COINS AND EXCLUSIVE ITEMS\r\n\r\nCustomise your cue and table! In every competitive 1-vs-1 match you play, there’ll be Pool Coins at stake – win the match and the Coins are yours. You can use these to enter higher ranked matches with bigger stakes, or to buy new items in the Pool Shop.\r\n\r\n<b>CHALLENGE YOUR FRIENDS<b></b>\r\n\r\nPlaying with friends is easy: sign in with your Miniclip or Facebook account and you’ll be able to challenge your friends straight from the game. Challenge friends anytime, anywhere and show off your skills.\r\n\r\n<b>LEVEL UP<b></b>\r\n\r\n8 Ball Pool’s level system means you’re always facing a challenge. Play matches to increase your ranking and get access to more exclusive match locations, where you play against
, accessible online or offline.<br><br>BLAST CANDIES WITH FRIENDS<br>- Match and pop candies to get to the top of the leaderboard! Compare scores with friends and find out who’s the match 3 master!<br>- Enjoy the sweetest of match 3 puzzle games around! <br><br>If you want to master and blast even more puzzles, you may also enjoy other games from King: Candy Crush Soda Saga, Farm Heroes Saga, and Pet Rescue Saga.<br><br>Candy Crush Saga is free to play but optional in-game items require payment. You can turn off the payment feature by disabling in-app purchases in your device’s settings.<br><br>By downloading Candy Crush Saga you agree to our terms of service which can be found at https://king.com/termsAndConditions<br><br>Do not sell my data: King shares your personal information with advertising partners to personalize ads. Learn more at https://king.com/privacyPolicy. If you wish to exercise your Do Not Sell My Data rights, you can do so by contacting us via the in-game help center or by going to https://soporto.king.com/contact',
#   'developer': 'King',
#   'installs': '1,000,000,000+'},
#  {'appId': 'com.dts.freefireth',
#   'icon': 'https://play-lh.googleusercontent.com/tM5rMqMkOPMyuRX_zKTWeVV6U2BvU2cMBILZmuIgjX_z9it3R_3aZZ0HwRLgxjvGGQ',
#   'screenshots': ['https://play-lh.googleusercontent.com/dt2034GepYYr_PC5dgAmXOPs0bO5zfRF6sDaTYEuzJbSpXpiCY9QW4IHeRgCJTc-a6g',
#    'https://play-lh.googleusercontent.com/cjvX6De-WxOGEFgDbnTlWG1bTxclL4mmsM5E1x0zhsUZS9Ml9mZsyGk4BhrXvNAUHA',
#    'https://play-lh.googleusercontent.com/De-OZAInDQCehxfa_hwXOJmO2fdDH5spTIdbUctmkYfro1Kde1xxyrl938DHpwFJ2EW-',
#    'https://play-lh.googleusercontent.com/gCqzyb8ruGTDTuF9obFEic9RhphCLWVaxiaBANtpBbUbf62vSi9bSMvQ04fjabv0y97v',
#    'https://play-lh.googleusercontent.com/WEdRc30NmZQha8DmrfP1eKccE3Ss8IuxvtDbXxXU-k2ddWWGPsKn9O_cHS--WJrBN8Q',
#    'https://play-lh.googleusercontent.com/oKgnk0GkGmtr9zEMg1oCTg5lglNtfeFoIeVxAtfpqabp6MGYudHkuL3mV77v_2EnSTc',
#    'https://play-lh.googleusercontent.com/yoQjtDB7-P3VurvGCTeoGYlCfkNYgSjqyDEFNEZqfrGHV56kUZEnbWZLa4Rmnq8lKjQ',
#    'https://play-lh.googleusercontent.com/Tzqyf-GWMY8q5cIrXKTIgAXg5H9eBuOa9OcGnXrlBczMMi8t73q1cMHmPqpzl34lvg',
#    'https://play-lh.googleusercontent.com/Tm4EfpMvYeciicr-YIgnvaMghmnt0dg4ZymWz1e-O33j6htjr_S6oo7ZefYL9uUmlEM',
#    'https://play-lh.googleusercontent.com/QxMY5VKucLeuszxZSGchYO0FRBEYw2Wg3kBSzRUjBrZiWfU8NO5KxPTQfV0klEi2_e_Y',
#    'https://play-lh.googleusercontent.com/1LcKUCsJ6c9xfUxc4W9Sauet9k2YnqvC-bja7TgwvJDXfteIpt_Sc3fJaZTrJP5xtvM6',
#    'https://play-lh.googleusercontent.com/Bp1QEORLoFBA3PPm0fYb0Y2-kaO0x7ihTPjPOtVP8ZcAhZQdXOt2kRTLf8q6_OXmeTY',
#    'https://play-lh.googleusercontent.com/tufx_LRE_owB4KWhwAGlfQq8wXO3ASGKktKLdys_ofhi0uAENpxkTBZjNBCe1nyUS84',
#    'https://play-lh.googleusercontent.com/iPR8GyhnMXvUX04g5H_FhrLIP2tC3VVQxUMrvM3Xb_U9C4xqX4FqeyLMaLk8yzqvW0s',
#    'https://play-lh.googleusercontent.com/624Rw0LIr5joRHP3DJ8TjZp0bqT1ya8c96Zycrw_rZj5ssWcRELMoNVmH6P6-q4jFJ7-',
#    'https://play-lh.googleusercontent.com/kvmwiE5uVWN5eJ_BMD6oW2b-Gif8L9eW2JQ8gPLkudNTUelGDZJg54bpAqIf0s5TiltY',
#    'https://play-lh.googleusercontent.com/YpUEddlgl8mtIdED_iEFEtzH91tg4XNJws4_enmaSJdwIkFQKg8lvPAn7MdVH-eB3Ng',
#    'https://play-lh.googleusercontent.com/BdE37CHz7OnRhfDWTyJRlSER2No-WKBg1ed_0pkf0qQqA4UBC9fGutLLBy407Clx2I8',
#    'https://play-lh.googleusercontent.com/TqiFb-uvpGnS9YZeXbwHSwqV5_eGNKvo3fjqt-Q2QeiptJR3O6Wp6rhosvUm1dx-p7qk',
#    'https://play-lh.googleusercontent.com/9TjLgkiUfGG6EO0RMyRGu-6IeuK9do3VIyf4dUqHWkL8f-fnYVFuS1T8RcMkNPVVj-w',
#    'https://play-lh.googleusercontent.com/aF_165G3S2gNEBijiwxuOwHxeFTsDMGf4uJkPJw2lkiJNL_jmEhRSCPtUDXncgoHHw',
#    'https://play-lh.googleusercontent.com/grIC3QrDvYoLmwAr_d4uTAAdpIr1oNw6xnK7JdxTm6NM8zkKL5lnTKUJtywJ2TA-Y89E'],
#   'title': 'Free Fire: The Chaos',
#   'score': 4.4307647,
#   'genre': 'Action',
#   'price': 0,
#   'free': True,
#   'currency': 'PKR',
#   'video': None,
#   'videoImage': None,
#   'description': "[New Event - The Chaos]\r\nWith the new event comes an exciting mechanism where players can vote for bizarre incidents to happen in the matches. Anything is possible - out-of-control airplane routes, genetically modified mushrooms, unusual Airdrop mechanisms... Seriously, anything!\r\n\r\n[NexTerra 2.0]\r\nZipway's terrain and artistic elements have been reworked, making the area much easier to loot in the new version and earning it a place in the CS-Ranked map pool.\r\nThe desert plains surrounding Deca Square and Mortar Ruins have been replaced by greenery and structures, expanding their lootable range.\r\nThere is also a bunch of other map-balancing adjustments for you to explore. Plus, the file size of NexTerra has been significantly reduced, so it now takes up much less device storage.\r\n\r\n[New Character]\r\nRyden, the 16-year-old inventive genius, releases a robotic spider that limits enemy movement and inflicts damage over time.\r\n\r\nFree Fire is a world-famous survival shooter game available on mobile. Each 10-minute game places you on a remote island where you are pit against 49 other players, all seeking survival. Players freely choose their starting point with their parachute, and aim to stay in the safe zone for as long as possible. Drive vehicles to explore the vast map, hide in the wild, or become invisible by proning under grass or rifts. Ambush, snipe, survive, there is only one goal: to survive and answer the call of duty.\r\n\r\nFree Fire, Battle In Style!\r\n\r\n[Survival shooter in its original form]\r\nSearch for weapons, stay in the play zone, loot your enem
#    'https://play-lh.googleusercontent.com/917aYT03GO3r3KJh7cD84c7eiHdWC2kcWTx9uebE2pNu434XoB3Btp3muk8zSFB32TY',
#    'https://play-lh.googleusercontent.com/NO7TUVL4vlr1U0PLnyexyhwoyfhIUmT7oG8s5fwQJCozC-2H1DW7XTUqOcpIPkqsilg',
#    'https://play-lh.googleusercontent.com/C0664ZQUL_I6hf0T1Hao_ks-ZLTSqcSwJq1ZOWmmBcN1AqpkpArYY2OLdVhn0_MirK0'],
#   'title': 'My Talking Tom',
#   'score': 4.16107,
#   'genre': 'Casual',
#   'price': 0,
#   'free': True,
#   'currency': 'PKR',
#   'video': None,
#   'videoImage': None,
#   'description': "Talking Tom is the cat making every day a fun adventure.\r\n\r\nPlayers adopt this virtual pet, keep him happy and help him explore his world.\r\n\r\n- Talking Tom can really talk\r\n- Fashion and furniture items to collect\r\n- Mini games add action, adventure and fun\r\n- Travel destinations are waiting to be explored\r\n- Photo albums to be filled with memories\r\n- And more\r\n\r\nFrom Outfit7, creators of My Talking Tom 2, My Talking Tom Friends, My Talking Angela 2 and My Talking Angela.\r\n\r\nThis app contains:\r\n- Promotion of Outfit7's products and advertising;\r\n- Links that direct customers to Outfit7’s websites and other apps;\r\n- Personalization of content to encourage users to play the app again;\r\n- YouTube integration to allow users to watch videos of Outfit7's animated characters;\r\n- The option to make in-app purchases;\r\n- Subscriptions which automatically renew at the end of a subscription period unless cancelled. You can manage and cancel your subscription any time via Settings in your Google Play account;\r\n- Items to purchase (available in different prices) using virtual currency, depending on the player’s progress;\r\n- Alternative options to access all functionalities of the app without making any in-app purchases using real money.\r\n\r\n\r\nTerms of use: https://talkingtomandfriends.com/eula/en/\r\nEEA privacy policy: https://talkingtomandfriends.com/eea/en/\r\nUS privacy policy: https://talkingtomandfriends.com/privacy/en/\r\nBrazil privacy policy: https://talkingtomandfriends.com/privacy-brazil/en/\r\nRest of the world privacy policy: https://talkingtomandfriends.com/privacy/en/\r\nCustomer support: support@outfit7.com",
#   'descriptionHTML': 'Talking Tom is the cat making every day a fun adventure.<br><br>Players adopt this virtual pet, keep him happy and help him explore his world.<br><br>- Talking Tom can really talk<br>- Fashion and furniture items to collect<br>- Mini games add action, adventure and fun<br>- Travel destinations are waiting to be explored<br>- Photo albums to be filled with memories<br>- And more<br><br>From Outfit7, creators of My Talking Tom 2, My Talking Tom Friends, My Talking Angela 2 and My Talking Angela.<br><br>This app contains:<br>- Promotion of Outfit7&#39;s products and advertising;<br>- Links that direct customers to Outfit7’s websites and other apps;<br>- Personalization of content to encourage users to play the app again;<br>- YouTube integration to allow users to watch videos of Outfit7&#39;s animated characters;<br>- The option to make in-app purchases;<br>- Subscriptions which automatically renew at the end of a subscription period unless cancelled. You can manage and cancel your subscription any time via Settings in your Google Play account;<br>- Items to purchase (available in different prices) using virtual currency, depending on the player’s progress;<br>- Alternative options to access all functionalities of the app without making any in-app purchases using real money.<br><br><br>Terms of use: https://talkingtomandfriends.com/eula/en/<br>EEA privacy policy: https://talkingtomandfriends.com/eea/en/<br>US privacy policy: https://talkingtomandfriends.com/privacy/en/<br>Brazil privacy policy: https://talkingtomandfriends.com/privacy-brazil/en/<br>Rest of the world privacy policy: https://talkingtomandfriends.com/privacy/en/<br>Customer support: support@outfit7.com',
#   'developer': 'Outfit7 Limited',
#   'installs': '1,000,000,000+'},
#  {'appId': 'com.gameloft.android.ANMP.GloftA8HM',
#   'icon': 'https://play-lh.googleusercontent.com/y1J3-OrqJIlezTtaung2sPOnHY9wS2hdJh26ADkwcc3kdZy4DTGyv94IN_YRvdKy0y4',
#   'screenshots': ['https://play-lh.googleusercontent.com/HL5AcvVnavAL5N5J_GaIjCNasUfbqbuEeK7PAf3XDbpnUMlrALr-GEoDysJdAHS2dK0',
#    'https://play-lh.googleusercontent.com/IJEYXzh0tcT-7RVENHRQYiVsyAii_Zdgi55Sth6AJYAcyA6293qK_Ldb8nGbEXs3QbE',
#    'https://play-lh.googleusercontent.com/amFFsu2k_u4hQtucY7ksto5objZmEA9bnjMJHOlgZAiHRjnJFQFAF5-OAw0Ir8KGyA',
#    'https://play-lh.googleusercontent.com/xLnb0Ord6mp4gRd_twtrto6tE_QD7upUN7J6Kh5TQJZYMazqz1Uj9ghwyD3kSHWbzwjS',
#    'https://play-lh.googleusercontent.com/KKB680fwOg1gqeis_2IOKWfyg2JVSm_Q9ARAZXidmVQC7izY5YNjrL3EZ5zQtiSXkkGY',
#    'https://play-lh.googleusercontent.com/3VYXoHxIte_SB2KTO9GujCh3jfwve9Bg6GG1AMT6X6dVo64aBgWeeaN7HFLmHGR8LDk',
#    'https://play-lh.googleusercontent.com/20RvpxzcOrKXvq6oWtM-FlLPEsvL3O4bnwhrNANhFUJxe6ZxBLJ-UlPaB_JvXMBaWu4',
#    'https://play-lh.googleusercontent.com/cBzGFtjLm2G1vIQirjPby4yPZ-nn8oj6rxsPWIwEdujGZR332G4wicBgmJtdfPHk4_4',
#    'https://play-lh.googleusercontent.com/6ZcTZyLeBHw-yjWpvAyNvBCX51i0hzkFfl3iTyGxy0vNCvo-kM3CL6zUfnrw63TuMvw',
# ...
#   'descriptionHTML': 'EA SPORTS FC™ MOBILE 24 is here. Join us in building the future of soccer today.<br> <br> Join the EA SPORTS™ soccer fan club! Train and build your dream Ultimate Team™ of legendary soccer stars and put them to the test. Collect Player Items of world-class talent like Vini Jr., Erling Haaland, Virgil van Dijk, and Son Heung-min. Play as Real Madrid from LALIGA EA SPORTS, or Manchester City from the Premier League and many more. Score goals with some of your favorite players as you level up your dream team of soccer / football stars from the 23/24 season. Compete against the best in PvP modes including Head-to-Head, VS Attack and Manager Mode.<br> <br> World-class competition, realistic sports game thrills, real time 11v11 gameplay, and authentic soccer game action awaits. Be a part of the next generation of mobile soccer gaming.<br> <br> NEXT-LEVEL GAMEPLAY<br> - True Player Personality: Reflecting authentic player characteristics, with tangible attribute impact and animation diversity<br> - Dynamic Game Speed: Mobile-first and tactile game speed, allowing for more player personality and attribute impact on the pitch<br> - Elite Shooting System: Realistic shot system allows impact players to make their mark<br> - Impact Controls: Power Shot, Hard Tackle and Knock On: Unlock new ways to score and defend <br> <br> IMMERSIVE NEXT-LEVEL SOCCER SIMULATION<br> - Immersive Broadcast Experience with new dynamic cameras and impactful replays<br> - Football fans can experience realistic stadium SFX and live on-field audio commentary<br> - Unlock stadiums and weather modes for an enhanced soccer matchday<br> <br> FOOTBALL LEGENDS, LEAGUES &amp; COMPETITIONS<br> - EA SPORTS FC MOBILE is home to the biggest competitions, leagues, and players across the world’s game with more than 15,000 fully licensed players, 650+ teams, and 30+ leagues<br> - Premier League, UEFA Champions League, LALIGA EASPORTS, Bundesliga, Ligue 1, Serie A, CONMEBOL Libertadores, and many more are playable throughout the season<br> - Get on the pitch with world soccer / football stars: Vini Jr., Erling Haaland, Jude Bellingham, Virgil van Dijk, Son Heung-min, Diogo Jota and many more<br> - Play with legendary soccer / football ICONs: Ronaldinho, Steven Gerrard &amp; Wayne Rooney<br> <br> UCL TOURNAMENT MODE<br> - Unlock all 32 qualified teams and play from group stage to final to become a Champion<br> - Experience the authentic UCL broadcasting package, UCL stadium art, official UCL ball and the iconic trophy ceremony<br> - Localized UCL commentary to bring the most immersive match atmosphere<br> <br> LOCKER ROOM CUSTOMIZATION<br> - Get a closer look at each soccer player on your roster<br> - Customize their look from kit to boots including Club Crest, Ball, Jersey, Kit, Kit style and Number <br> <br>Welcome to the club.<br><br>This app: Requires acceptance of EA’s User Agreement and Privacy &amp; Cookie Policy. Do Not Sell My Personal Information: https://tos.ea.com/legalapp/WEBPRIVACYCA/US/en/PC/ Requires an Internet connection (network fees may apply). Allows players (above the minimum age of digital consent in their country) to communicate via League chat; to disable for users under the age of majority with League chat access, use your device&#39;s parental controls. Includes in-game advertising. Contains direct links to the Internet and social networking sites intended for an audience over 13. The app uses Google Play Game Services. Log out of Google Play Game Services before installation if you don’t want to share your game play with friends. This game includes optional in-game purchases of virtual currency that can be used to acquire virtual in-game items, including a random selection of virtual in-game items. FC Points not available in Belgium.<br><br>User Agreement: terms.ea.com<br>Privacy and Cookie Policy: privacy.ea.com<br>Visit help.ea.com for assistance or inquiries.<br>EA may retire online features after 30 days’ notice posted on ea ...
#   'developer': 'ELECTRONIC ARTS',
#   'installs': '100,000,000+'},
#  {'appId': 'com.supercell.clashofclans',
#   'icon': 'https://play-lh.googleusercontent.com/LByrur1mTmPeNr0ljI-uAUcct1rzmTve5Esau1SwoAzjBXQUby6uHIfHbF9TAT51mgHm',
#   'screenshots': ['https://play-lh.googleusercontent.com/qkMIWX-JY6TS-9UEsvWc05x-6XZOhsCS5HHXHDZJGVh6Gv-5W-t7ghUyhD4X-uWcSD4',
#    'https://play-lh.googleusercontent.com/A5ivtMq98cCIZr4jSv0Xg4wsnGgfnlrqgAMzJwQtJe9mM2r1jdsv00OSw1Jo366mwuAF',
#    'https://play-lh.googleusercontent.com/tWB1iKhOCXRHxtp-mW4XISA6XD-gECwDJhZKGHuyc9LhM_ZSCnVSMd1rYAgV9aHcrIYt',
#    'https://play-lh.googleusercontent.com/NyweFity8rN7fOSKMkAVwJWdgP10sEeDHZmMpILfZoJMmoiqlJfJvRYbn_yNFhDhk74K',
#   'developer': 'Supercell',
#   'installs': '500,000,000+'}]

# %%
len(result)
# Out:
# 25

# %%
for app in result:
    app_info = google_play_scraper.app(app["appId"])
    print(app_info.keys())
    break
# Out:
# dict_keys(['title', 'description', 'descriptionHTML', 'summary', 'installs', 'minInstalls', 'realInstalls', 'score', 'ratings', 'reviews', 'histogram', 'price', 'free', 'currency', 'sale', 'saleTime', 'originalPrice', 'saleText', 'offersIAP', 'inAppProductPrice', 'developer', 'developerId', 'developerEmail', 'developerWebsite', 'developerAddress', 'privacyPolicy', 'genre', 'genreId', 'categories', 'icon', 'headerImage', 'screenshots', 'video', 'videoImage', 'contentRating', 'contentRatingDescription', 'adSupported', 'containsAds', 'released', 'updated', 'version', 'comments', 'appId', 'url'])

# %%
for app in result:
    app_info = google_play_scraper.app(app["appId"])
    print(app_info['title'])
    print(app_info['summary'])
    print(app_info['realInstalls'])
    print(app_info['score'])
    print(app_info['ratings'])
    print(app_info['reviews'])
    print(app_info['genre'])
    break
# Out:
# Subway Surfers
# Help Jake, Tricky & Fresh escape from the grumpy Inspector and his dog!
# 2337376600
# 4.5721645
# 41094222
# 1788158
# Arcade

# %%
# Create a list to store the data
data = []
for app in result:
    app_info = google_play_scraper.app(app["appId"])
    
    data.append({
        "Id":app["appId"],
          "title": app_info["title"],
          "summary": app_info["summary"],
          "realInstalls": app_info["realInstalls"],
          "Average_rating": app_info["score"],
          "Ratings_recieved": app_info["ratings"],
          "Reviews_recieved": app_info["reviews"],
          "price": app_info["price"],
          "developer_name": app_info["developer"],
          "genre": app_info["genre"]

        })

# %%
import pandas as pd

df = pd.DataFrame(data)
df.head(2)
# Out:
#                          Id              title  \
# 0      com.kiloo.subwaysurf     Subway Surfers
# 1  com.fingersoft.hillclimb  Hill Climb Racing
#
#                                              summary  realInstalls  \
# 0  Help Jake, Tricky & Fresh escape from the grum...    2337376600
# 1  Race uphill to win in this offline physics bas...    1042159697
#
#    Average_rating  Ratings_recieved  Reviews_recieved  price developer_name  \
# 0        4.572165          41094222           1788158      0     SYBO Games
# 1        4.527524          10810872            380386      0     Fingersoft
#
#     genre
# 0  Arcade
# 1  Racing

# %% [markdown]
# ### Function for all the above steps

# %%
def retrieve_apps(category):
    
    result = search( category, lang="en", country="pk")
    
    # Create a list to store the data
    data = []
    for app in result:
        app_info = google_play_scraper.app(app["appId"])
        
        data.append({
            "Id":app["appId"],
              "title": app_info["title"],
              "summary": app_info["summary"],
              "number_of_installs": app_info["realInstalls"],
              "Average_rating": app_info["score"],
              "Ratings_recieved": app_info["ratings"],
              "Reviews_recieved": app_info["reviews"],
              "Ratings_histogram": app_info["histogram"],
              "price": app_info["price"],
              "developer_name": app_info["developer"],
              "genre": app_info["genre"]
        })
    
    df = pd.DataFrame(data)
    return df

# %%
df = retrieve_apps("social media")
df.to_csv("social_media_apps_info.csv",index=False)

# %%
import pandas as pd

df = pd.read_csv("social_media_apps_info.csv")
df.shape
# Out:
# (22, 11)

# %%
df.head()
# Out:
#                          Id      title  \
# 0     com.instagram.android  Instagram
# 1       com.twitter.android          X
# 2  com.zhiliaoapp.musically     TikTok
# 3      com.snapchat.android   Snapchat
# 4       com.facebook.katana   Facebook
#
#                                              summary  number_of_installs  \
# 0  Create & share photos, stories, & reels with f...          5371302851
# 1  The X app is the trusted digital town square f...          1521681297
# 2  Join your friends and discover videos you love...          2987141158
# 3                                  Share the moment!          2872690946
# 4                        Explore the things you love          9348137692
#
#    Average_rating  Ratings_recieved  Reviews_recieved  \
# 0        4.007182         152150356           4494912
# 1        3.794807          21663393            740064
# 2        4.265024          61935191           2175160
# 3        4.055221          34076735           1753614
# 4        3.644068         138953396           4195492
#
#                                   Ratings_histogram  price  \
# 0  [26845188, 5099144, 7262455, 13854430, 99089103]      0
# 1      [5355041, 475926, 570820, 2118961, 13142628]      0
# 2    [6913476, 1795925, 3013001, 6453139, 43759624]      0
# 3    [5130201, 1316663, 2131691, 3460758, 22037400]      0
# 4  [35795972, 5816655, 7878187, 12021139, 77441422]      0
#
#          developer_name          genre
# 0             Instagram         Social
# 1               X Corp.         Social
# 2      TikTok Pte. Ltd.         Social
# 3              Snap Inc  Communication
# 4  Meta Platforms, Inc.         Social

# %% [markdown]
# ### Let's Scrap reviews for each application

# %%
app_reviews, continuation_token = reviews("com.kiloo.subwaysurf",sort=Sort.NEWEST)

# %%
app_reviews
# Out:
# [{'reviewId': '36513ab6-42bb-4102-b3d8-cdcffa63128c',
#   'userName': 'Yash Bhansali',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJZ75CAEl7BTDG_qY46k9An4BDVuhQUKVxk6ZlSN1tT=mo',
#   'content': "This Game is really good Amazing good. The music fits perfect well when your on the run, But not just all, when you bump into any obstacle, the guard shows up and he keeps chasing you and he did a weird annoying growl which is so funny.😀 I kept playing over and over again until I got really addicted to it. I even played it back at the few years. The gameplay looks great and game itself is funny and when you run so quick, this becomes satisfying. :)😌. So it's, 5 star rating😁 Thank you, SYB0:)",
#   'score': 5,
#   'thumbsUpCount': 299,
#   'reviewCreatedVersion': '3.25.0',
#   'at': datetime.datetime(2024, 2, 20, 19, 3, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.25.0'},
#  {'reviewId': 'b0046481-c774-40fb-a9b9-06869dbc6eb4',
#   'userName': 'Mariah Moreno',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKiPDxmOokLQlALltaMaNRRlm51OIZsMy71LaDQW4u5=mo',
#   'content': "I used to play subway surfer when it first came out, but this new Verizon is updated and it's amazing. The graphics 10/10, Characters 10/10, music 10/10. Overall everything about this game is good. Yeah it has ads but so you can get things, like power ups and such. And I believe you can play off line I haven't tried yet but for ads off line, you won't be able to do anything. But you can still play the game if you don't have wi-fi you just have limited stuff.",
#   'score': 5,
#   'thumbsUpCount': 299,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 20, 0, 28, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.1'},
#  {'reviewId': '5a16cad6-2286-4175-96cc-66bdee5c8574',
#   'userName': 'Lilly White',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXqTs-Y__rz9e5KtVEkQvbQA73zRi4KfKhHMV_J3gJR3Q',
#   'content': "This is a great game for raid trips if you don't have Wi-Fi or service or if your really bored I really recommend it if you're looking for an offline game you can play anywhere at any time!!! There's not very many problems maybe like a lag or two but that just depends if you have Wi-Fi or service... And every few months they always change the category and I always look forward to seeing what new stuff they have!! :))",
#   'score': 4,
#   'thumbsUpCount': 2563,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 2, 6, 8, 51, 33),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.0'},
#  {'reviewId': 'aa96e985-6d0a-47c6-a747-cb3122716ca0',
#   'userName': 'game mask',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIvhjrcBiBnZCxg9Y6M7EuqOBduROIw8CPlb4-l5SXj=mo',
#   'content': 'But I would like the jackpot to be a bit easier to get. Because it takes forever to just unlock that badge. And it would be fun if we had more things to get with coins. Overall, this is a very great game. It is fun seeing the different characters come in the shop where we can buy them with coins and it would help if event coins cared over for the next season shop.',
#   'score': 4,
#   'thumbsUpCount': 1864,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 1, 29, 20, 3, 57),
#   'replyContent': "Thanks for sharing your thoughts with us. However, we're sad to see only a few stars from you and would love to get 5 stars. Please contact us if you have additional feedback or any issues with the game: reviews@sybogames.com Thanks again for your review. We really appreciate it.",
#   'repliedAt': datetime.datetime(2024, 1, 23, 20, 32, 53),
#   'appVersion': '3.24.0'},
#  {'reviewId': 'a7e9cdb4-33cd-4873-bb8f-6641d3cc2b26',
#   'userName': 'Pen Lee',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW9ZiPUZNq-Eo9x9a0faf4r-jeWyopu4NR15rjpWo7xi4Q',
#   'content': 'I got back into the game recently, and have experienced one issue multiple times: if I watch an ad to regenerate and click on it at all - which takes me out of the ad and into a pop up browser - it breaks my game. Going back to the Subway Surfers tab will present me with a blank screen, and though the ad countdown is still in the corner, the X will never pop up when the ads over. In order to play the game, I have to exit out of the app entirely and load back in, which invalidates my entire run.',
#   'score': 2,
#   'thumbsUpCount': 715,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 2, 7, 5, 3, 26),
#   'replyContent': 'We really appreciate your feedback. Can you tell us what we would need to do to get 5 stars from you? For any issues with the game or for additional feedback, check out our FAQ or contact us at: reviews@sybogames.com We love hearing feedback and ideas from our players!',
#   'repliedAt': datetime.datetime(2024, 2, 8, 6, 40, 4),
#   'appVersion': '3.24.0'},
#  {'reviewId': '0d71e9a5-591e-4514-8efc-b173b33a2bdb',
#   'userName': 'M Poblo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW7Vn36jT7zdC3_LMGcptrcap9PKY-o0G5GRZdxGKL76A',
#   'content': 'It\'s great!! There\'s just a lot of "connection issues" even when my connection is fine. Happens with multiple phones too, so it\'s not me. It doesn\'t give me awards for ads I\'ve watched (forcing me to watch another ad), can freeze on the option to waste keys or watch an ad for a revive (which forces to restart the game all the way), and just a lot of bugs/glitches. This game is amazing and a wonderful time waster... But it does suck to have a 2+ million run ruined due to "connection issues"',
#   'score': 3,
#   'thumbsUpCount': 1436,
#   'reviewCreatedVersion': '3.22.1',
#   'at': datetime.datetime(2024, 1, 7, 9, 42, 14),
#   'replyContent': "Thanks for your time and review. How could we make our game a 5-star experience? You can seek help for any game-related issues you might face on our support site - feel free to write us there as well: reviews@sybogames.com Let's help you get a better experience!",
#   'repliedAt': datetime.datetime(2024, 1, 8, 13, 14, 47),
#   'appVersion': '3.22.1'},
#  {'reviewId': 'c43fc677-7851-4561-a528-7d146c208e41',
#   'userName': 'Aurianna Dodge',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWZEXGvC0ifoTPBfyLsDJolJszg34TMNvp4WgkZRKCZZW8',
#   'content': "It's a great game full of childhood memories... but with all the events and online stuff that comes with it, I can't even play this offline. Without the internet, the game is extremely slow to load, and it often lags. It's really sad and kills the experience I once had with this amazing game. I would love for the game to be fixed. The events are awesome, but I would like to be able to once agian play offline without lag or outright getting kicked out of the game.",
#   'score': 3,
#   'thumbsUpCount': 870,
#   'reviewCreatedVersion': '3.23.1',
#   'at': datetime.datetime(2024, 1, 28, 3, 26, 7),
#   'replyContent': "Thank you very much for rating the game and leaving a review. You didn't give it many stars, and we would like to earn more! If you have more feedback or encounter an issue with our game, please visit our FAQ or contact us at: reviews@sybogames.com We would like to hear more from you!",
#   'repliedAt': datetime.datetime(2024, 1, 29, 7, 28, 20),
#   'appVersion': '3.23.1'},
#  {'reviewId': 'cc5476d5-f93d-44f8-8b01-6c0924644b45',
#   'userName': 'Anna',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIQ75_WRNkFdCwHNxpTVi7KdHtMVdNeriK_B4IDzC40=mo',
#   'content': "BUG REPORT Total points for obtaining listed characters and boards do not add up correctly. It falls short of required amount. It doesn't acknowledge completion. ------------------------ The game's Tech Support is great. They helped me get all of my hard earned characters back. I've been playing this game for years and accumulated many characters and boards, so having access to them again made me very happy :) This is one of my favorite go-to games when I want to destress and just veg.",
#   'score': 4,
#   'thumbsUpCount': 2703,
#   'reviewCreatedVersion': '3.22.0',
#   'at': datetime.datetime(2024, 1, 4, 3, 48, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.22.0'},
#  {'reviewId': 'bd39be73-6803-422c-8f58-25f5e298b72b',
#   'userName': 'Lee Lupo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWRAXJz_ksiV3eigd42R9cAxto27BEfWNg-coesq19DgUbC',
#   'content': "UPDATED: It is one of the best games in the Play Store. Plenty of ads with rewards, but they're optional. Refreshing. Celebrated its 10-year anniversary. Congratulations. UPDATE: There's a problem with the game freezing while playing the Lunchables video for challenge rewards. The freeze crashes the game, and wipes out the progress you've made in your challenge.",
#   'score': 5,
#   'thumbsUpCount': 12024,
#   'reviewCreatedVersion': '3.23.0',
#   'at': datetime.datetime(2024, 1, 13, 3, 28, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.23.0'},
#  {'reviewId': '8135d1c4-831f-4d79-90fe-0e4510fbe82d',
#   'userName': 'Chloe A',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIW2YWJf9t7j_VfBM65nSKIEyxSt8zQO100G2_KawlOBg=mo',
#   'content': "It's a fun thing to do with your hands while you're paying attention to something else. I used to listen to YouTube while playing, but the fact that there's constant video ads that interrupt the videos is irritating. I have to go into airplane mode and watch the video on a different device in order to get the experience that I want. The hourglass challenge is also stupid. It's entirely based on luck and where the hourglasses spawn. At least the no floor thing was somewhat skill.",
#   'score': 2,
#   'thumbsUpCount': 3526,
#   'reviewCreatedVersion': '3.23.0',
#   'at': datetime.datetime(2024, 1, 9, 0, 38, 15),
#   'replyContent': 'We really appreciate your feedback. Can you tell us what we would need to do to get 5 stars from you? For any issues with the game or for additional feedback, check out our FAQ or contact us at: reviews@sybogames.com We love hearing feedback and ideas from our players!',
#   'repliedAt': datetime.datetime(2024, 1, 10, 2, 13, 1),
#   'appVersion': '3.23.0'},
#  {'reviewId': '037ec92e-dc8a-4b06-9007-702a59f2d743',
#   'userName': 'Elizabeth',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU0t-P0AWCa82CsSAH2cGQhKLXfek8J9Lop1kR93sgl5Q',
#   'content': "Literally the best game known to mankind, this was my whole childhood. The ads aren't annoying, I personally love to listen to music and podcasts while playing, the events and challenges are unique and fun everything about this is great. I'm surprised people rate it low. My friends and family have all played and is using this app. It is such a recognizable game and I personally love it. It has given me something to focus on while listening to music or podcasts.",
#   'score': 5,
#   'thumbsUpCount': 739,
#   'reviewCreatedVersion': '3.23.0',
#   'at': datetime.datetime(2024, 1, 24, 9, 59, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.23.0'},
#  {'reviewId': 'cfdbf88a-6757-47bb-87e2-bf6d3d83707c',
#   'userName': 'Like the Doo Dah Man Truckn On',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWs_dTIcawkKUpyCaLfu8bjq3GHd0RFFdx79OYy7pjKsu8',
#   'content': "I'm totally digging it, the controls, game boards, special abilities and rewards are all on point. You can really come up by watching adds but you aren't made to watch them. I just started playing but I haven't found anything that usually turns me away from games. I would add a spray painting graffiti board to the game if I was on the Dev team ;)",
#   'score': 5,
#   'thumbsUpCount': 2011,
#   'reviewCreatedVersion': '3.22.1',
#   'at': datetime.datetime(2023, 12, 23, 18, 58, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.22.1'},
#  {'reviewId': '3167c65f-fb51-47e8-9382-b703e27d137e',
#   'userName': 'Rose Dilly',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLYjxm7W6SCShiDPlNmt34J3-aK8dVrNHajC3aCjujw8g=mo',
#   'content': "There are some problems with the game but overall good game I'd give it 5 stars but it is not perfect. Some things they really need to fix is the get a reward for playing every day I'm a student so I can't play it every day and I forget to do it when I get home so I either watch a ad or spend keys I know people would probably go for the ad so they can keep their keys to save up but I really hate ads so please make it like a week or something not a month it would help! Thank you sorry it's long.",
#   'score': 3,
#   'thumbsUpCount': 4874,
#   'reviewCreatedVersion': '3.21.1',
#   'at': datetime.datetime(2023, 11, 30, 1, 51, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.21.1'},
#  {'reviewId': '73fe2d38-7519-4d1f-b8ca-5684de2268bd',
#   'userName': 'Aeva Mason-McDonald',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJWuFN9KS3AOhcsjr8UnU5O7QBM0nSjHQ8hNDuWgLbq=mo',
#   'content': "I love subway surfers so much I play it all the time , and I love all the season changes, and I love the rewards,and the challenges too , but there's so much ads, and it takes so much to just get one character, like skye you have to run over 2 million to get her , and miss Maia, you need 100 keys to get her. But other than that it is really great I love it. It's actually my favorite game to play , so keep up the great work !",
#   'score': 5,
#   'thumbsUpCount': 302,
#   'reviewCreatedVersion': '3.23.1',
#   'at': datetime.datetime(2024, 2, 1, 6, 55, 34),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.23.1'},
#  {'reviewId': 'ee44d8b3-a9a7-4f2b-9e10-15e49f352742',
#   'userName': 'Laura Wright',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUgWyTLpw73adJ4tRHKtaLNp11E7OpyXlHrh2uIt_2GLYg',
#   'content': 'Subway Surfers is an amazing game. I have loved to see it change over the years and love all of the new features that have been added. Although I gave the game overall a 5 star review, in Subway Surfers, my music does not work. I have checked that it is turned on, it is not muted, and the volume is turned all the way up on the game and on my phone. Please fix this or alert me how to. I always enjoy being able to experience the wonderful tunes. I would highly recommend to download this game.',
#   'score': 5,
#   'thumbsUpCount': 260,
#   'reviewCreatedVersion': '3.23.1',
#   'at': datetime.datetime(2024, 1, 27, 3, 49, 47),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.23.1'},
#  {'reviewId': '8b1dbb5c-1ec7-4115-afe6-4c6ff5267a81',
#   'userName': 'Ian Reyes',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJPDcX4YARCJNS_NKbpuMrsizA5dYvHpAJAinIotG3S=mo',
#   'content': 'Subway Surfer is an exhilarating mobile game that deserves every bit of its 5-star rating. The endless runner concept is brilliantly executed, providing a perfect balance of challenge and excitement. The vibrant and dynamic graphics create a visually appealing experience, while the diverse landscapes keep the gameplay fresh and engaging. With a wide array of characters and power-ups, Subway Surfer offers endless possibilities for customization and strategy.',
#   'score': 5,
#   'thumbsUpCount': 993,
#   'reviewCreatedVersion': '3.21.1',
#   'at': datetime.datetime(2023, 12, 5, 22, 12, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.21.1'},
#  {'reviewId': 'd2ee9486-b3cb-44ec-8fd1-d93526a6e59c',
#   'userName': 'Steve Hatley',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIqJBK1Mgcm7vm7b5eabDO8-GGF0PxGn53B80VRRSEz=mo',
#   'content': "Can't get hover boards to load. No matter how many times I tap the screen, no matter which lane the runner is in. I might download the game again IF the issue gets fixed. Maybe. (Edit) After a few weeks and a couple exchanged emails in which the developer suggested my device is the issue. However the device malfunction Only occurs on this app. Don't waste your time downloading this worthless app. I wish I could give it a Zero star rating!",
#   'score': 1,
#   'thumbsUpCount': 440,
#   'reviewCreatedVersion': '3.23.0',
#   'at': datetime.datetime(2024, 1, 20, 9, 0, 44),
#   'replyContent': "Thanks for letting us know! We were sad to see you rated our game at 1-star, as we aim to deliver you a 5-star experience. Check our FAQ or contact us at: reviews@sybogames.com if you have any issues with the game or additional feedback. We'd love to help and learn more!",
#   'repliedAt': datetime.datetime(2024, 1, 21, 10, 42, 29),
#   'appVersion': '3.23.0'},
#  {'reviewId': '93b4d215-67be-4ad5-a824-40ab50948147',
#   'userName': 'Dillon Renfrow',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVJ2bDEU4QOGLzL9O9D8nmKfyj5OR6gD0ZAoEbHXhxNKZA',
#   'content': "Okay So it's a really fun game in my opinion but this new update has a lot of bugs that's why I'm giving it 1 star. You see there's alot trains invisible, obstacles, roofs, the ground are also invisible half of the time. I've never had this happen before until this update, and half of the time when I try to load the game it kicks me off, but I'm pretty sure that's just my phone. Anyway please fix all the bugs.",
#   'score': 1,
#   'thumbsUpCount': 1246,
#   'reviewCreatedVersion': '3.23.0',
#   'at': datetime.datetime(2024, 1, 11, 3, 45, 27),
#   'replyContent': "Thanks for letting us know! We were sad to see you rated our game at 1-star, as we aim to deliver you a 5-star experience. Check our FAQ or contact us at: reviews@sybogames.com if you have any issues with the game or additional feedback. We'd love to help and learn more!",
#   'repliedAt': datetime.datetime(2024, 1, 12, 6, 17, 2),
#   'appVersion': '3.23.0'},
#  {'reviewId': 'a34de34b-73ac-4c1e-a653-44d0dd5903d8',
#   'userName': 'thatonekid intheback',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVeYwdR1apZiVRWP3dwCZYN505DdqEPjilWEbTWEiCREz8',
#   'content': "The game is great. But there is a problem that could possibly be from my phone. Every time I get a ad for Lego fortnite, (like to get rewards I missed or respawn after death) it glitches out after three seconds and kicks me out of the ad as the x pops up. It says there's a connection issue, but my wifi is perfectly fine and any other ad works fine. Also, Sometimes when I die, and click to use a key, i won't respawn but it takes my keys, so that REALLY annoys me. please fix key glitch.",
#   'score': 4,
#   'thumbsUpCount': 269,
#   'reviewCreatedVersion': '3.22.1',
#   'at': datetime.datetime(2023, 12, 20, 1, 44, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.22.1'},
#  {'reviewId': '65f1426f-a645-4ee5-a2e2-45e38ae81322',
#   'userName': 'Jessica Mcclintic',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJuLSw8nzLMuJL_rZ7ll5J7sw_Sw4_nrxBqaor2aeue=mo',
#   'content': "I used to love this game until this one tik tok ad popped up and ruined it. There is no exit button. It doesn't time out at 30 seconds. I have to restart the whole app. And of course nothing gets saved bc I'm in the middle of a run. Definitely not my phone as all other ads work fine, just that one black screen tik tok ad. I wish they would review their ads to make sure they are working properly. Sigh. Game is fun to unwind to otherwise. I enjoy the challenge.",
#   'score': 2,
#   'thumbsUpCount': 31257,
#   'reviewCreatedVersion': '3.17.1',
#   'at': datetime.datetime(2023, 9, 14, 3, 59, 26),
#   'replyContent': "Thanks for letting us know! We were sad to see you didn't give our game many stars, as we aim to deliver you a 5-star experience. Check our FAQ or contact us at: reviews@sybogames.com if you have any issues with the game or additional feedback. We would love to help and learn more!",
#   'repliedAt': datetime.datetime(2023, 9, 15, 7, 21, 53),
#   'appVersion': '3.17.1'},
#  {'reviewId': 'e0e2fb77-9d7f-4d61-aeb9-cbeebb6bf54a',
#   'userName': 'Hazelnut JAM',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUmi4rEexkoeHvS9awQh7ol2khg64e0R2pIGr-0MBF8G1c',
#   'content': "This game has improved tremendously since the first time I played it(2016)! Many fun new challenges and good graphics! Keeps you entertained. Love it! I'm also wondering what the point of collecting sneaks after completing quests is if you can't even use the sneaks to buy anything. Also, I wish it was easier to get more keys instead of having to buy them with real money, wish there was an option to spend like 20000 surfer coins to get like 10 keys for example.",
#   'score': 5,
#   'thumbsUpCount': 6951,
#   'reviewCreatedVersion': '3.20.0',
#   'at': datetime.datetime(2023, 11, 19, 20, 18, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.20.0'},
#  {'reviewId': 'c98f758c-75d2-4e4c-9f76-b45c98533fbd',
#   'userName': 'xia!',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU44l4HuRyuXaAKMt4pNbnHaaePDF9UmoU-uJXS7RsmwKE',
#   'content': "This is an excellent time-killer. However, it requires a lot of side-grinding. Infact, this season's character and board are to be acquired as rewards in Quests, which is notoriously hard (timed). As a student, I can't dedicate so much time to grind. I understand that it's no fun if things are too easy, but getting Season Specials should be much easier. Otherwise, it's definitely my go-to game. Warning: it's addictive! <3",
#   'score': 3,
#   'thumbsUpCount': 7033,
#   'reviewCreatedVersion': '3.20.0',
#   'at': datetime.datetime(2023, 11, 12, 16, 6, 16),
#   'replyContent': 'We really appreciate your feedback. Can you tell us what we would need to do to get 5 stars from you? For any issues with the game or for additional feedback, check out our FAQ or contact us at: reviews@sybogames.com We love hearing feedback and ideas from our players!',
#   'repliedAt': datetime.datetime(2023, 11, 13, 19, 57),
#   'appVersion': '3.20.0'},
#  {'reviewId': '5028e78d-d4dd-4846-9fcd-4cefa15720c0',
#   'userName': 'Willow Epp',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVHEzmxcKY_WKX0NFeVJPwnv2Hax_JAtesoJ7U1k1hz9oI',
#   'content': "It's decently fun, though it feels a lot like attrition is the best way to get high scores. In this, it reminds me a lot of Jetpack Joyride with a different perspective. Controls are responsive for an action game on a phone but dang if normal buttons wouldn't be better than swiping! The worst thing is all the basing nagging for money and ad watching. Also, you can't start with a girl character, which is annoying even though it doesn't affect gameplay.",
#   'score': 3,
#   'thumbsUpCount': 13829,
#   'reviewCreatedVersion': '3.18.0',
#   'at': datetime.datetime(2023, 9, 19, 1, 3, 14),
#   'replyContent': 'We really appreciate your feedback. Can you tell us what we would need to do to get 5 stars from you? For any issues with the game or for additional feedback, check out our FAQ or contact us at: reviews@sybogames.com We love hearing feedback and ideas from our players!',
#   'repliedAt': datetime.datetime(2023, 9, 20, 6, 36, 9),
#   'appVersion': '3.18.0'},
#  {'reviewId': 'b71b081a-c063-4777-a3b3-ceb65829fc3b',
#   'userName': 'Ezra Snow',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWjRXCTJEuwc1mR47TuJMm_A8H2wAw5O7n3k9hWNy13cryd',
#   'content': "Great game. I've been playing it for over 2 years now. Only problem is, I usually like to listen to my own music when playing Subway Surfers, and recent updates have made that more annoying on Android. When I open Subway Surfers while music is playing, the music is paused. Resuming it results in ALL Subway Surfers Sounds being MUTED, even though they don't show as such. It's like y'all forgot that the ingame music is easy to mute. Please fix this. It didn't used to do that. Other than that, 👍👍",
#   'score': 4,
#   'thumbsUpCount': 3380,
#   'reviewCreatedVersion': '3.18.1',
#   'at': datetime.datetime(2023, 10, 1, 5, 20, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.18.1'},
#  {'reviewId': 'bd0a2864-bc0e-40b8-ab44-5906c5030f68',
#   'userName': 'Myra Geter',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV0A7UGgJlK46UW6SWXeptWom2RZ57BjlwLcObx5W0M2w',
#   'content': "This game was a core childhood memory, so when I was trying to find a good offline road trip game and came across Subway Surfers, I couldn't help but buy it. Not only is it fun, there is so much you can do! Daily challenges for endless possibilities. I love, Love, LOVE this game to death. Especially for long car rides. My family goes on plenty of road trips and sometimes it gets boring. Subway Surfers IS THE ANSWER. Totally would recommend for any cenario.",
#   'score': 5,
#   'thumbsUpCount': 1384,
#   'reviewCreatedVersion': '3.21.0',
#   'at': datetime.datetime(2023, 11, 26, 5, 13, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.21.0'},
#  {'reviewId': '07a78860-2224-4cd8-963e-1cd0c4ca2d1b',
#   'userName': 'Lizzy Sm',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJFq4W5gZXI2peNdq_CqF4HotaIU4dkRRN5zBhBcn_F=mo',
#   'content': "I love this game from when I was a kid, I love some of the new changes but I feel like coins are a little to hard to get. Also I love the way the new season hunts work I think it's a good change. U should definitely download, I feel like it's a little annoying on how there are many ads but I do like how they give you rewards for the more ads you watch. Overall a fun game but it lost the last star due to something stupid and many people that used to play this game but u can't listen to the music.",
#   'score': 4,
#   'thumbsUpCount': 1574,
#   'reviewCreatedVersion': '3.18.0',
#   'at': datetime.datetime(2023, 9, 19, 6, 37, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.18.0'},
#  {'reviewId': 'ca51567d-6550-4616-8df6-48e7c8f26f70',
#   'userName': 'Bob Kusnetz',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXrAQQiDasEvsJzyD7LNmWyGGoyL9t-DsFVAWqtZvUirpY',
#   'content': 'When I started playing Subway Surfers just after it was released (oh so many years ago), the first purchase I made was double coins. I am no longer getting double coins. Also, after every run, I get a pop-down notice telling me "Coin Counter Complete". True, but I completed that achievement years ago, and there\'s no way to clear the message.',
#   'score': 3,
#   'thumbsUpCount': 565,
#   'reviewCreatedVersion': '3.17.1',
#   'at': datetime.datetime(2023, 9, 12, 20, 8, 36),
#   'replyContent': "Thanks for letting us know! We were sad to see you didn't give our game many stars, as we aim to deliver you a 5-star experience. Check our FAQ or contact us at: reviews@sybogames.com if you have any issues with the game or additional feedback. We would love to help and learn more!",
#   'repliedAt': datetime.datetime(2023, 9, 14, 1, 59, 43),
#   'appVersion': '3.17.1'},
#  {'reviewId': '0b1796a1-6817-4616-8870-aec5c32de3f1',
#   'userName': 'Gabriella Calloway',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUgR6yNyajrGY8jtJdHvNGOzZ6AQXnlCf7_GD-i6Q4dwPw',
#   'content': "I enjoy the game it's really amazing but I do have a few qualms one being after a few times of being on the app it kinda just stops. Like it freezes at the loading page and no matter how long I wait it does not load in. So I have to reset the game all together for it to let me get back on. Another thing I'd even though I sign in none of my progress is ever saved",
#   'score': 3,
#   'thumbsUpCount': 589,
#   'reviewCreatedVersion': '3.21.0',
#   'at': datetime.datetime(2023, 11, 24, 13, 54, 35),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.21.0'},
#  {'reviewId': 'b793bfa5-5188-4a25-8ec4-c37b51351f7e',
#   'userName': 'Party For You',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJvAFuLHcHg2o8qvw5bGR0mVujH_9yH6Q9UUtAhhwVW=mo',
#   'content': "Just came back after several years hiatus. Was enjoying this game non stop for the last several days then suddenly my game glitched and is stuck. Every time I close and re-open, same thing. I was at the end of a run so I'm probably going to lose everything if I have to uninstall and re-install. Crazy being that I've been using games on phones for about 8 yrs and this is the ONLY game I've ever played that real life glitched. The Wreck it Ralph movie keeps coming to mind.",
#   'score': 3,
#   'thumbsUpCount': 2320,
#   'reviewCreatedVersion': '3.18.0',
#   'at': datetime.datetime(2023, 9, 25, 11, 25, 31),
#   'replyContent': "Thanks for letting us know! We were sad to see you didn't give our game many stars, as we aim to deliver you a 5-star experience. Check our FAQ or contact us at: reviews@sybogames.com if you have any issues with the game or additional feedback. We would love to help and learn more!",
#   'repliedAt': datetime.datetime(2023, 9, 26, 14, 52, 11),
#   'appVersion': '3.18.0'},
#  {'reviewId': 'e5dd690f-ba9a-4f3e-a9f1-78be0c98f66e',
#   'userName': 'Bean',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU35Lxzd1NscPqFov-z6IeCbgcVKH5ikHvfVy7F8-dG45Y',
#   'content': "A decent game but I just experienced a few glitches, a minor annoyance and a game-breaking bug. One glitch was where dust was coming from a character's feet constantly and it prevented rolling so you could only jump and move. Another glitch is the game constantly saying I completed an achievement and to collect it but I can't since I've already collected it(Coin Counter is the achievement) which has been happening since the Tokyo update. Also there needs to be more items that cost coins.",
#   'score': 3,
#   'thumbsUpCount': 2088,
#   'reviewCreatedVersion': '3.18.0',
#   'at': datetime.datetime(2023, 9, 22, 6, 16, 15),
#   'replyContent': "Thanks for letting us know! We were sad to see you didn't give our game many stars, as we aim to deliver you a 5-star experience. Check our FAQ or contact us at: reviews@sybogames.com if you have any issues with the game or additional feedback. We would love to help and learn more!",
#   'repliedAt': datetime.datetime(2023, 9, 23, 13, 27, 59),
#   'appVersion': '3.18.0'},
#  {'reviewId': '22b9d569-2083-4992-92c0-26ec1a197627',
#   'userName': 'Alexa Beauchamp (YGT)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUsKYdzpD8rHO9KNo8IcvmTI6AlftakND5ET-DzlZwIaCQ',
#   'content': "One. Billion. Downloads. AND THIS GAME DESERVES THEM! I love this game. It's fun, easy to play, and it isn't pay to win! You can obviously pay for in game items, but it isn't necessary. You can pay in-game keys to continue in your run, or watch and ad, and I think that's amazing! I haven't had a single problem before! This game deserves ♾️/5!",
#   'score': 5,
#   'thumbsUpCount': 482,
#   'reviewCreatedVersion': '3.19.0',
#   'at': datetime.datetime(2023, 10, 30, 3, 58, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.19.0'},
#  {'reviewId': 'c5767a6d-b3af-4e48-99af-6dd916864021',
#   'userName': 'Colton Monnier',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIzVCdmenHegnqmBLDlVQfGadGYKWn9itTjDPiZ74s9=mo',
#   'content': "I enjoy the game quite a bit but once you get good enough it's just a game of endurance, I would rather have a hard mode at some point where the points counter goes up faster because having a run for over an hour gets boring. Also I agree with other reviews about buying more characters with coins. Overall, it's a good game.",
#   'score': 4,
#   'thumbsUpCount': 2183,
#   'reviewCreatedVersion': '3.20.0',
#   'at': datetime.datetime(2023, 11, 7, 10, 9, 29),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.20.0'},
#  {'reviewId': 'b080e475-22bc-4f18-b186-e5089b958e36',
#   'userName': 'Tyler Woods',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLwBw2JwryH-SA8QI0YptwSqNh2ZMVTdyXXBTuHsutL=mo',
#   'content': "I'm kind of leaving this as a rage review. great game overall, but when I was on my best run yet I had over 700,000 points I died. Me dying is fine but when I went to do the revive it gave me a add that doesn't work (it's Tik-Tok. Someone else who reviewed this described it) and whenever I get those ads it ends the run. I get those ads constantly. But pretty good game overall. (Edit the add went away and my new score wasn't counted I was going to leave four stars)",
#   'score': 3,
#   'thumbsUpCount': 257,
#   'reviewCreatedVersion': '3.18.2',
#   'at': datetime.datetime(2023, 10, 4, 7, 16, 52),
#   'replyContent': "Thanks for letting us know! We were sad to see you didn't give our game many stars, as we aim to deliver you a 5-star experience. Check our FAQ or contact us at: reviews@sybogames.com if you have any issues with the game or additional feedback. We would love to help and learn more!",
#   'repliedAt': datetime.datetime(2023, 10, 5, 12, 45, 51),
#   'appVersion': '3.18.2'},
#  {'reviewId': 'bf24a2e2-3700-48aa-bdcf-19cb64e272ec',
#   'userName': 'Bubby',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWwAUbSg_-U_RCH-5uYb2xeNV7vbkP-3vVwAkNvBYsL-Vf2',
#   'content': "My favourite game even after all these years. I always come back to it. I do really dislike that you can not collect all the event awards as much as you want. I've just played for a while after eachother and now it's telling me I can only collect awards again after 19+ hours. This is really demotivating and makes the game less fun.",
#   'score': 4,
#   'thumbsUpCount': 211,
#   'reviewCreatedVersion': '3.25.0',
#   'at': datetime.datetime(2024, 2, 20, 9, 35, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.25.0'},
#  {'reviewId': '8616bbc5-45c3-4ab5-9fa4-0074cbc0ceba',
#   'userName': 'Tanishi Goyal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLpE83TZjNQizRyeiVqYub0LsQpySs09c5GuRgmZP7q=mo',
#   'content': "Subway Surfers is a blast of childhood memories and modern excitement rolled into one. The game's good humor, both in-game and on Instagram, adds a playful touch to the experience. Despite growing up, I still find the game engaging, especially with its constant updates like new maps, characters, and game modes. My favorite map is the underwater theme, and I wish it could stay forever. As for game modes, I love the challenge of no floor and mystery hurdles, keeping me hooked for hours on end.",
#   'score': 5,
#   'thumbsUpCount': 4267,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 14, 5, 37, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.1'},
#  {'reviewId': '75d3464f-df91-485b-a761-65c8603a27c2',
#   'userName': 'Angela Lin',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVHVVnAGBUB4T1ZoRaTRpwG9atLZPEY_gzyQu0NwYqUYw',
#   'content': "This is a straight-up AWESOME game that can be played with or without Wi-Fi and is a good game to play when bored. It helps with improving your mental-physical connection, finger movement, and reaction timing. The only problem I have found is that this game can sometimes lose your progress. When I was doing two of their events, I had gone long and far into a run, which would have earnt me a reward, but it didn't count that run, and I lost all progress. If they fix that bug, guaranteed 5-stars.",
#   'score': 4,
#   'thumbsUpCount': 3398,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 1, 29, 17, 9, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.0'},
#  {'reviewId': '1cc069d1-0c50-4e38-9b0a-ed43f20680cd',
#   'userName': 'Helena Blitsas',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJx-MBrE3iKqz6Oh0yXfjM4uClAn4MkFSgENMxOjK4WAg=mo',
#   'content': "This game is literally the best! It is perfect for either somebody who want a quick 5 minute game or a game that you can play for hours! With regularly updated missions and seasons, Subway surfers makes it fun no matter when you're playing. In never foces you to pay for things and you can challenge people all over the world to get the no.1 spot! I cannot recommend this enough!",
#   'score': 5,
#   'thumbsUpCount': 51,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 19, 9, 51, 1),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.1'},
#  {'reviewId': '6775f209-fe93-48aa-8883-bd156c9f319c',
#   'userName': 'Wau Wau',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXvC1KuDqBnV-NwXclUZXjR2vM4GUfpVLcECuArQVpREA',
#   'content': 'This game is very fun to play. But, there is one problem. The ads. For some reason, whenever I want to watch ads for rewards, it didn\'t let me get the reward. Instead, it just stuck saying "Reward in 1 second" next to the X button. (Especially the Disney | Fossil ad) Please fix it or remove the ads if it can\'t be fixed. Edit: Why did your game keep giving me Disney | Fossil ad? You have a lot of sponsorship in your game yet you keep giving an ad that doesn\'t even give me rewards. 😤',
#   'score': 4,
#   'thumbsUpCount': 1872,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 2, 8, 14, 35, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.0'},
#  {'reviewId': '3401cc35-72c6-4453-b2ab-1392224de983',
#   'userName': 'Evan Burns',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWThcxL9_5rN0iqdQCDlQjexiDSsbWOvURSGtqIOsAYqH8',
#   'content': "Greedy Devs. For a game with over 1 billion downloads they sure love putting in intrusive ads. Watching ads for rewards is totally fine, 8 ball pool do that and it works perfectly. But if I decide to not watch an ad don't then force me to watch another one for no reward. Utterly nonsensical especially given all the opportunities for in-app purchases. Just a cut and dry example of the greed that's ruining the app game industry. 🖕",
#   'score': 3,
#   'thumbsUpCount': 149,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 16, 14, 30, 19),
#   'replyContent': 'Your review of our game is important to us. What would it take to earn a 5-star rating from you? Please contact us if you need help with any game-related issues or if you have more feedback: reviews@sybogames.com Feedback from our players is super valuable to us.',
#   'repliedAt': datetime.datetime(2024, 2, 17, 18, 56, 2),
#   'appVersion': '3.24.1'},
#  {'reviewId': '1dbf9800-07b1-430f-adc2-60fae466c30a',
#   'userName': 'Aliyah Laureen Lim',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWRZvbIbmwhItZG-mizqJw9E14h-Pr6tgwqHcWReH8YXrw',
#   'content': "This game is very entertaining, which you can play it offline. Although you can play it offline, to unlock some features like the events, some rewards, and a lot more, it's a bit annoying when you have no internet connection and you want to participate in games. To summarize it all, this game is VERY GOOD despite the other disadvantages I've seen.",
#   'score': 4,
#   'thumbsUpCount': 3064,
#   'reviewCreatedVersion': '3.23.1',
#   'at': datetime.datetime(2024, 1, 29, 7, 31, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.23.1'},
#  {'reviewId': 'cede73c3-c95b-43df-b3bd-6796b45dfb4e',
#   'userName': 'ev gnks',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJF98B3g1HMw0q_NiNY3V9gHVbZCg39qxKRqviUKBpP=mo',
#   'content': "That's a classic game I've been playing since my childhood. I still enjoy playing it. But there's a noticeable change that made me slowly lose interest in this game. The characters since 2020 look different but worse in design and colors. It would be way better with their first classic subway surfers design. Now they look too round like cringe nickelodeon 3d cartoons. The old characters had better coloring and shading. Plus, all the new characters have weird futuristic clothes that are ugly.",
#   'score': 3,
#   'thumbsUpCount': 231,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 2, 9, 1, 41, 46),
#   'replyContent': "Thank you very much for rating the game and leaving a review. You didn't give it many stars, and we would like to earn more! If you have more feedback or encounter an issue with our game, please visit our FAQ or contact us at: reviews@sybogames.com We would like to hear more from you!",
#   'repliedAt': datetime.datetime(2024, 2, 10, 7, 55, 46),
#   'appVersion': '3.24.0'},
#  {'reviewId': '5d3c7113-aedb-41fb-bc6b-afedda670db3',
#   'userName': 'Flashyy-Brawl Stars',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUbBKZaDoSaaIzPJQuEsHrKQyuJlElPr5S0yb_3XisxpQ',
#   'content': "I have been playing this game for 7 years already now, and I gotta say that this game is my childhood. However, I spotted bugs with the Ad System. There's a poor selection of advertisements to watch to get rewards or save yourself on a run, and I sometimes run into the problem when there's no countdown until the ad ends, it just stays like that. Also, most of the time ads are unavailable. If you fix it, I'll rate it 5 stars. Edit: Thank you, now it's better.",
#   'score': 5,
#   'thumbsUpCount': 11592,
#   'reviewCreatedVersion': '3.21.1',
#   'at': datetime.datetime(2023, 12, 11, 10, 33, 24),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.21.1'},
#  {'reviewId': '025eaa95-ef8a-4129-8015-aaeeaf239864',
#   'userName': 'Sikumi Mey',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU5gsgZSb0RQg28OiyunUdUmzfeGtWtgib8JHfEchhdSjEb',
#   'content': 'I like the game, but every few updates it stops supporting the "split screen" function and it\'s one of the only times I play it: while watching a YouTube video. I\'ve been a loyal player for years, I watch a lot of ads, complete all the events religiously every day. But the split screen is a deal breaker, I\'ve deleted the game over it before, and it had been fixed when I redownloaded. But not anymore. I dislike when there are avatars that you have to buy for buffs. I watch like 20 ads a day !',
#   'score': 3,
#   'thumbsUpCount': 1232,
#   'reviewCreatedVersion': '3.23.1',
#   'at': datetime.datetime(2024, 1, 21, 3, 28, 13),
#   'replyContent': "Thank you very much for rating the game and leaving a review. You didn't give it many stars, and we would like to earn more! If you have more feedback or encounter an issue with our game, please visit our FAQ or contact us at: reviews@sybogames.com We would like to hear more from you!",
#   'repliedAt': datetime.datetime(2024, 1, 22, 7, 23, 36),
#   'appVersion': '3.23.1'},
#  {'reviewId': 'e8d9cd58-9bed-47fa-8cc8-fa4f17a79185',
#   'userName': 'ExoticWaffle',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUrO-_6GMpmnyBJ8bni-mFZxGjdAJEJLEyAm2g_Xi8PAHoB',
#   'content': "It's nice. I just find it really annoying that when I get a new character or a board it's automatically equipped. Sometimes I'll forget to change back to my usual board with superjump and superspeed and it ruins my run. Not a big deal in main mode, I can just restart, but it's really annoying in events since there's the cooldown times. So I'd give a higher rating if there was an option to stop the auto equip.",
#   'score': 3,
#   'thumbsUpCount': 4291,
#   'reviewCreatedVersion': '3.22.1',
#   'at': datetime.datetime(2023, 12, 29, 17, 1, 44),
#   'replyContent': "Thanks for letting us know! We were sad to see you didn't give our game many stars, as we aim to deliver you a 5-star experience. Check our FAQ or contact us at: reviews@sybogames.com if you have any issues with the game or additional feedback. We would love to help and learn more!",
#   'repliedAt': datetime.datetime(2023, 12, 30, 18, 11, 18),
#   'appVersion': '3.22.1'},
#  {'reviewId': '1f2e3944-53d4-454e-b9f8-76e39c7a769f',
#   'userName': 'Laiba khalid',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUtmmN52dYBO1v2n2evaofU5q-0E5z6tHw_wNiYHRwbxqI',
#   'content': 'Subway Surfers" is an exhilarating endless runner game set in various vibrant locations around the world. Players navigate subway tracks, avoiding obstacles and collecting coins. The game\'s dynamic graphics and smooth controls make it engaging, while regular updates introduce new challenges and themes. The diverse characters and hoverboards add a personal touch to the gameplay. However, some may find the in-app purchase system a bit aggressive.',
#   'score': 5,
#   'thumbsUpCount': 12523,
#   'reviewCreatedVersion': '3.21.1',
#   'at': datetime.datetime(2023, 12, 11, 13, 33, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.21.1'},
#  {'reviewId': 'bee730d0-5bd9-47a2-9c51-c0f7728ec8c8',
#   'userName': 'Lindy Joy Jabagat',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXwFlUEIZX62tqYn10-YJvDICfIRzKNDPo0b8QmlQmEhQ',
#   'content': "I've been playing this for a long time now, it has a nice graphics and the power ups are super cool, but these fast few weeks there's a little bit of problem's. too much taking time to load the highest number of scores, the events , and etc. even though I do have a stable internet connection. But to sum it up it's still cool i like this game.",
#   'score': 4,
#   'thumbsUpCount': 1399,
#   'reviewCreatedVersion': '3.22.0',
#   'at': datetime.datetime(2024, 1, 12, 18, 40, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.22.0'},
#  {'reviewId': '0b9e52c1-f426-4728-9b4a-7df6a260a6f7',
#   'userName': 'Nicolette Pettemeridou',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUcPMCCqVXREvE6BtnVHoD5SkLmVmy4SHkEVc2mb0Gini0',
#   'content': "classic game, simple and entertaining. but lately, EVERYTHING is just pay-to-win. any special/event surfer, boards etc. edit: the game would be a lot better if you could buy more stuff with coins/keys/event tokens instead of ONLY having the option of paying real money, since it's a simple game that not a lot of people play fanatically",
#   'score': 2,
#   'thumbsUpCount': 139,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 12, 19, 50, 17),
#   'replyContent': 'Thanks for your feedback. What can we do to get 5 stars and not just a few stars from you? More feedback is always welcome. Contact us at reviews@sybogames.com You can also find help with any issue with the game you might have. Please let us know how we can improve!',
#   'repliedAt': datetime.datetime(2024, 2, 13, 20, 29, 19),
#   'appVersion': '3.24.1'},
#  {'reviewId': 'd413ec16-b1be-44a5-b0c7-df7f1674c0a2',
#   'userName': 'Marina_K',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLSv5KvAS9LWeyhC67Ca8fTU0aCT6jcM9AL0uU60uIQ9Rk=mo',
#   'content': 'Subway Surfers is an all-time classic, sitting on the top of the "running games" list. It is a super smooth, lag-free game, which allows you to move faster and more complex, unlocking its full potential. Moreover, there are lots of events that used to be non-existent in the past. However, obtaining one of its new-styled characters without purchasing them with real-world money is almost impossible. That being said, money (or ads) is often required, but that doesn\'t make it less enjoyable.',
#   'score': 4,
#   'thumbsUpCount': 343,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 2, 3, 15, 45, 36),
#   'replyContent': "Thanks for the review. We would love to get a 5-star rating for our game from you. Our FAQ could help if you're having issues with our game. Feel free to contact us with more feedback as well at: https://sybo.zendesk.com/. Hope we can be of help.",
#   'repliedAt': datetime.datetime(2021, 7, 2, 5, 30, 5),
#   'appVersion': '3.24.0'},
#  {'reviewId': 'c9f765c3-7768-42d7-a363-fb80067b431c',
#   'userName': '_3ameqitx',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjURww2DV8MwQ83AjFAagQSqvVN3dzvFhQhwpHJSvmRuS01K',
#   'content': 'The game is great and a very fun experience when you are bored. BUT I recently changed phones and I lost all my progress and the limited characters I had on my previous phone. I would really appreciate it if this was fixed and we could transfer the data on our old phone to the new one. I really enjoy this game and I play it very often but I was very disappointed when I lost all my progress and my stuff such as my characters,keys,boards and the coins. Thank you for your time.',
#   'score': 3,
#   'thumbsUpCount': 36,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 12, 16, 17, 44),
# ...
#   'content': 'Very fun game to play when your bored and is frequently updated with new events seasons and more. Has in game purchases for any big spenders and also has free rewards as well. Leaderboard system seems a little bit bugged but hopefully should be fixed. Over all great game though.',
#   'score': 4,
#   'thumbsUpCount': 33,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 2, 3, 4, 42, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.0'},
#  {'reviewId': '32ea9a0c-a61b-4985-9950-f3809cf9d33a',
#   'userName': 'Anisha Shaw',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLnEyPwiFr0BfmWka16jxaycFZxiOfIBtC_glXP8f6j=mo',
#   'content': 'I love this game so much because it is a time consuming game and when you feel like bored or something you can turn on your phone and can play it...and you can play it offline also and one more thing I will highly recommend you to download this game..and there are many many updates and you can enjoy each and every update offline by clicking on the events option I love this game so much',
#   'score': 5,
#   'thumbsUpCount': 43,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 1, 31, 20, 19, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.0'},
#  {'reviewId': 'ffab911d-cb9b-4e38-851f-e279a6b4a936',
#   'userName': 'Kamla Narwal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJxEbrwNxEMXmNgwZaXFOtmJdGQ0-zT0CbuCWYud0EV=mo',
#   'content': "Nice game 👍 and the no floor challenge is a bit too hard when we reach level 4 we have to cover too much distance but season challenge is a lot more easy than no floor challenge pls make it easy No complaints other than that music is also very nice my favourite is the Seoul one, also pls don't ask real money on virtual things like I feel very annoyed that half of the characters need money to have",
#   'score': 5,
#   'thumbsUpCount': 25,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 2, 2, 8, 54, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.0'},
#  {'reviewId': '7a1b47bd-1d1f-4314-9f93-88d595a2e3bd',
#   'userName': 'Semilore Adeleye',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLx5TUddVdActU6sj8uo5vLnWlUTWciR7aj80sLP9fV=mo',
#   'content': "The game is a nice game, I've been playing this game since when I was little and to be honest it's really good and addictive. But the reason for the two star is that since I updated it, I've loyall my progress in the game and if I should not play the game for like a day it would start from the very beginning as if I just downloaded it.pls I don't know if it's a bug or something but pls fix it.",
#   'score': 2,
#   'thumbsUpCount': 15,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 2, 6, 3, 54, 41),
#   'replyContent': "Thanks for your time and review. How could we make our game a 5-star experience? You can seek help for any game-related issues you might face on our support site - feel free to write us there as well: reviews@sybogames.com Let's help you get a better experience!",
#   'repliedAt': datetime.datetime(2024, 2, 7, 6, 51, 49),
#   'appVersion': '3.24.0'},
#  {'reviewId': '5c881548-bf3c-4115-bd63-b144f16c1c41',
#   'userName': 'Aadilah Wardha',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJR-ibcLys4erj_Ck2UULdoIVxLFVtV362rEsvGccB5=mo',
#   'content': 'This game used to be my entire childhood. I used to play this alot. Now I see alot of changes are added like seasons and events. The moment I got my own phone I downloaded this so I can go back to my childhood. This is the best game ever. During my higher exams subway surfers gave me a break and helped me to survive',
#   'score': 5,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 19, 5, 41, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.1'},
#  {'reviewId': 'd34656c4-0b2c-4e6e-9cee-e1f1d51ea4ff',
#   'userName': 'Russell Pence',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJdCnLC5ZtiGfvPw25fqu8IuSuYTB9e-gFtJtKaqQIG=mo',
#   'content': 'Game can be fun. There is one particular ad for rewards and revival that gets halfway through and kicks off saying connection error. Very annoying. Cannot get rewards. Cannot revive. I would recommend against this game until they get the issue resolved.',
#   'score': 1,
#   'thumbsUpCount': 65,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 11, 23, 10, 31),
#   'replyContent': "Thanks for sharing your thoughts with us. However, we're sad to see a 1-star rating for our game and would love to get 5 stars. Please contact us if you have additional feedback or any issues with the game: reviews@sybogames.com Thanks again for your review. We really appreciate it.",
#   'repliedAt': datetime.datetime(2024, 2, 13, 2, 0, 45),
#   'appVersion': '3.24.1'},
#  {'reviewId': '3b42403d-147a-4faf-9411-e9e0f416d7b0',
#   'userName': 'jaden jones',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU961r4aBlIa0xgpVWHgKKhfCP35iDWM40VAQlJ_2TLsg',
#   'content': 'Honestly this game is forever my childhood. Simple running mechanics, great graphics, and the characters. Also I wish there is a online race where you can compete with players around the world, but although this is a best game I have ever played',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 2, 19, 10, 19, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.0'},
#  {'reviewId': '06c2a228-5eff-4540-ba9e-a12146c42e44',
#   'userName': 'Isabella Jacobson',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX3KBeCv0CTizAsy4vdeVA7tU5FqEf38dDrh4by8SX-GNw',
#   'content': "Subway Surfers is so much fun! You bored and don't know what to play? Well get subway surfers to keep you entertained. You can unlock so many characters and boards. While trying to beat your highscore. Also compete in events against your friends every day. When you unlock new characters you can also unlock new outfits and power ups. I give this game five stars and if you don't have subway surfers get it now!",
#   'score': 5,
#   'thumbsUpCount': 11,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 15, 3, 5, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.1'},
#  {'reviewId': 'c7e9530b-7204-4d16-9252-68849a4111f9',
#   'userName': 'nconnell 77',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW_R4bqczr4gIjdLo1JvTTeKGSbjQ7a57r4OjwsYnDe76Q',
#   'content': "Fun game but almost unplayable with the amount of ads that pops up I want to play the game I don't mind one ad but not every single time I die and or when an ad pops up out of no where and you can't skip it cuz it's a game ad and have to wait for couple of seconds in order to skip it I'm playing subway surf not this. and annoying is thing is this game didn't require internet back in the day so why now so you guys can run ads all time and get ad revenue. I liked it how it was back in the past.",
#   'score': 1,
#   'thumbsUpCount': 28,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 10, 4, 28, 15),
#   'replyContent': "Thanks for letting us know! We were sad to see you rated our game at 1-star, as we aim to deliver you a 5-star experience. Check our FAQ or contact us at: reviews@sybogames.com if you have any issues with the game or additional feedback. We'd love to help and learn more!",
#   'repliedAt': datetime.datetime(2024, 2, 11, 6, 23, 40),
#   'appVersion': '3.24.1'},
#  {'reviewId': '039a25aa-a4de-41db-8194-d5e438b5902a',
#   'userName': 'Daniel Obuobi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV2CzQfO1XFgERMEJCHpGCaBmjzNZWrvXJwMie_q90jNkA',
#   'content': "The game is awesome. A few setback is when you compete with friends during a week. When a new week starts you don't get to compete with those friends again. It gives you some random players with the highest score being less 300000.",
#   'score': 4,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 15, 14, 42, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.1'},
#  {'reviewId': '5654d202-fdff-499e-88bd-bd99bfde5a48',
#   'userName': 'Asya Fiona Rose',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKk1CK8Wge1yIW5t1LO0Luut6vXcJhUWhSqsg_0DK2J=mo',
#   'content': 'so there are 2 gazillion adds And everytime in playing I press an add to rewind and whenever I want to press an add it freezes and gets off the game 5 times in a row now The first time I got a really good high score and it never saved it but it saved how much money I spent and the second time it was even better it was 1000000 but THE STUPID ADD FROZE AND LOST IT and again it for SOME REASON it saved how much keys I spent Your getting money by spamming adds evreytime SO FIX YOUR GAME 😃',
#   'score': 1,
#   'thumbsUpCount': 14,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 14, 0, 44, 22),
#   'replyContent': 'Your review of our game is important to us. What would it take to earn a 5-star rating from you? Please contact us if you need help with any game-related issues or if you have more feedback: reviews@sybogames.com Feedback from our players is super valuable to us.',
#   'repliedAt': datetime.datetime(2024, 2, 15, 1, 27, 2),
#   'appVersion': '3.24.1'},
#  {'reviewId': 'b4c22759-d115-45bc-b557-7f709c084057',
#   'userName': 'Amelie Brown',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJz56rgJxZl5VvYBRz797bzgN3Jh1fJLgVCXK3XNqFX=mo',
#   'content': "I gave this a 3⭐️ because its a good game but like my OCD kicks in a bit when it comes to like the quests and things and I just think I need to do them before I play so that's a star gone and the second thing is that there's kinda lots of traps that you don't know are coming so that's a star gone but the 3 stars are for smooth jumps on the game and I love the characters and for last star it's just a good game after all😁",
#   'score': 3,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 17, 23, 39, 24),
#   'replyContent': 'We really appreciate your feedback. Can you tell us what we would need to do to get 5 stars from you? For any issues with the game or for additional feedback, check out our FAQ or contact us at: reviews@sybogames.com We love hearing feedback and ideas from our players!',
#   'repliedAt': datetime.datetime(2024, 2, 19, 1, 55, 15),
#   'appVersion': '3.24.1'},
#  {'reviewId': '60975cd3-e1bb-41e1-9b97-ed58a4a6c90b',
#   'userName': 'K. Grayson Joel Ackerbrooks (Joel)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU0-enGygdy4krGBM01FgtuZWkqzlEZ9Abr5CmeOMqZVtE',
#   'content': "Got the game yesterday to satisfy the feeling of watching those reddit AITA videos and they don't get all the coins Very good game on its own actually. Used to play a clone or two when I was a tad younger and have realized this game isn't easy to rage at when you lose and I admire that It thrives in its simplicity and is a classic Always loved the style of the game 10/10 would recommend",
#   'score': 5,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 17, 23, 18, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.1'},
#  {'reviewId': '81253818-261b-4e5a-8fc4-565ddbdaea62',
#   'userName': 'Xzerriana Fisher',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI8xwq9pfzDVYGXNeg4KRAl6wN-RrvOI9u7zMdzb1Vb=mo',
#   'content': "The best game ever but I would recommend that it's easier to get skins because I don't have enough money for that much money but if you could lower the price that would be so helpful but place to get the cars to get the golden skin you have to do this do not do this and that the next to that and I don't got time to do all that but it's a beautiful game love it I love how you change the things to.",
#   'score': 2,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 16, 6, 38, 7),
#   'replyContent': "Thank you very much for rating the game and leaving a review. You didn't give it many stars, and we would like to earn more! If you have more feedback or encounter an issue with our game, please visit our FAQ or contact us at: reviews@sybogames.com We would like to hear more from you!",
#   'repliedAt': datetime.datetime(2024, 2, 17, 10, 41, 46),
#   'appVersion': '3.24.1'},
#  {'reviewId': '38565ed9-be12-423b-b531-62d76ba86d06',
#   'userName': 'Kousar Jehan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXz3SHfee4jGBN28VC_NRYtfYlplFfhoD39EiRcoGqk',
#   'content': "Subway surfer is a good game and never ending but most of the time it hangs by it self.the game use all keys buy it self and most of the times my money and characters are gone by it self so then I have to start it again buy again the same characters and earn my all money.most of the times it didn't allow me to enter for more than 20 hours..",
#   'score': 1,
#   'thumbsUpCount': 16,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 2, 5, 23, 14, 50),
#   'replyContent': 'Your review of our game is important to us. What would it take to earn a 5-star rating from you? Please contact us if you need help with any game-related issues or if you have more feedback: reviews@sybogames.com Feedback from our players is super valuable to us.',
#   'repliedAt': datetime.datetime(2024, 2, 7, 0, 39, 45),
#   'appVersion': '3.24.0'},
#  {'reviewId': '608f6e11-89d7-41cc-96db-a03aeab76f04',
#   'userName': 'Ashlynn Johnson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJx-v7dgdqwCFVdpCgmQCZT-Z4Tfwr_GPu-YejrR7Zr=mo',
#   'content': 'I would give this 0 stars if I could. The game took away all of my event coins when I logged on the next day. This really upset me because iI worked so hard for days to save up for a limited character, and it all went to waste. Developers of Subway suffer please give me back all of my event coins back. I would highly appreciate it.',
#   'score': 1,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 19, 1, 25, 8),
#   'replyContent': 'We really appreciate your feedback. Can you tell us what we would need to do to get 5 stars from you? For any issues with the game or for additional feedback, check out our FAQ or contact us at: reviews@sybogames.com We love hearing feedback and ideas from our players!',
#   'repliedAt': datetime.datetime(2024, 2, 20, 6, 54, 15),
#   'appVersion': '3.24.1'},
#  {'reviewId': '043b3dc3-014d-4d29-8bc2-eba77c5b695c',
#   'userName': 'Kairi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWSkEXe_54roGcEj9vEgwlQa36mLdraN1eOtyWshLuDAlg',
#   'content': "Used to play it lots years ago, sadly times change and now it's full of adverts and stuff to buy in their shop. But overall it kept its original theme when it comes to gameplay with new nice events and better maps.",
#   'score': 4,
#   'thumbsUpCount': 10,
#   'reviewCreatedVersion': '3.24.1',
#   'at': datetime.datetime(2024, 2, 9, 15, 43, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.1'},
#  {'reviewId': '3d37b5e6-9c0e-427d-ac96-4e5478f622b4',
#   'userName': 'Arantza Sánchez',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKkIRrJKjYr5Iv54r8uhPu0ZspvCArcBhDZlHKhUP2oAQ=mo',
#   'content': "I love this game, I've been playing it for years, I had to stop playing because of school, and when I finally downloaded it again I noticed that it runs really slow now, I tried to get used to it, but it's getting really annoying that I have to use hoverboards all the time to speed up, I think the speed that it had before was nice, is it just mine or did the speed really got reduce?",
#   'score': 4,
#   'thumbsUpCount': 22,
#   'reviewCreatedVersion': '3.24.0',
#   'at': datetime.datetime(2024, 1, 29, 21, 15, 50),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.0'}]

# %%
for app in app_reviews:
    print(app.keys())
    break
# Out:
# dict_keys(['reviewId', 'userName', 'userImage', 'content', 'score', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt', 'appVersion'])

# %%
def scrap_reviews(input_csv_file, output_csv_file):
    # Read the input CSV file into a DataFrame
    df = pd.read_csv(input_csv_file)

    # Process each row in the input DataFrame
    for index, row in df.iterrows():
        app_id = row['Id']

        # Fetch the reviews for the app
        app_reviews, _ = reviews(
            app_id,
            sort=Sort.NEWEST
        )

        # Create a DataFrame for the reviews
        reviews_df = pd.DataFrame(app_reviews)

        # Add 'Id' column
        reviews_df['Id'] = app_id

        
    # Save the reviews DataFrame to a CSV file
    reviews_df.to_csv(output_csv_file, index=False, encoding='utf-8')

    print(f"Reviews retrieval completed and saved to {output_csv_file}.")

# %%
# Call the function to fetch and save reviews
scrap_reviews('social_media_apps_info.csv', 'reviews.csv')
# Out:
# Reviews retrieval completed and saved to reviews.csv.

# %%
reviews = pd.read_csv("reviews.csv")
reviews.head(2)
# Out:
#                                reviewId     userName  \
# 0  da624d22-16c7-4db7-8ff7-f75e984df467  Yuri Bobbio
# 1  55b9ff11-ce2c-484a-9132-501e09b6ce2b   BruhDuhMan
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  This app is fun to use, but there are some iss...      3           1456
# 1  This app definitely has potential, but i do ha...      3           1756
#
#   reviewCreatedVersion                   at  \
# 0      7.12.1626942404  2021-08-04 01:35:37
# 1      7.13.1631519493  2021-09-17 08:48:53
#
#                                         replyContent            repliedAt  \
# 0  Hello, dear user! We are really upset that you...  2021-08-04 11:04:37
# 1  Hello, dear user! We are really upset that you...  2021-09-17 11:14:44
#
#         appVersion                      Id
# 0  7.12.1626942404  com.sgiggle.production
# 1  7.13.1631519493  com.sgiggle.production

# %%
reviews["Id"].value_counts()
# Out:
# Id
# com.sgiggle.production    100
# Name: count, dtype: int64

# %% [markdown]
# ## Data Visualization Report

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Bar chart for Number of Installs
plt.figure(figsize=(10, 5))
sns.barplot(x='title', y='number_of_installs', data=df)
plt.xticks(rotation=45, ha='right')
plt.yticks(np.linspace(min(df['number_of_installs'] ),max(df['number_of_installs']),10), rotation=45)

plt.title('Number of Installs for Social Media Apps')
plt.show()

# %%
# Histogram for Ratings
plt.figure(figsize=(8, 5))
sns.histplot(df['Average_rating'], bins=20, kde=True)
plt.title('Distribution of Ratings for Social Media Apps')
plt.show()

# %%
# Pie chart for Genre Distribution
plt.figure(figsize=(4, 4))
df['genre'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Genre Distribution of Social Media Apps')
plt.show()

# %%
plt.figure(figsize=(6, 4))

genre_counts = df['genre'].value_counts()
plt.bar(genre_counts.index, genre_counts.values,color=sns.palettes.mpl_palette('Dark2'))
plt.title('Genre Distribution of Social Media Apps')
plt.xlabel('Genre')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Word Cloud for App Summary
from wordcloud import WordCloud

text = ' '.join(df['summary'].astype(str))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for App Summary')
plt.show()

# %%
text = ' '.join(reviews['content'].astype(str))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for App Review')
plt.show()
